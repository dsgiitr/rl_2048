# %%
import gym
from gym import spaces
from gym.utils import seeding
import itertools
import logging
import numpy as np
from collections import deque
import itertools

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.optimizers import Adam
from keras import layers

# %%
#Importing the Game Board
from Game_Board import*
max_tile=[]

# %%
#Converting observations in range (0,1) using log(n)/log(max) so that gradients don't vanish
def process_log(observation):
        observation = np.reshape(observation, (4, 4))
        observation_temp = np.where(observation <= 0, 1, observation) 
        processed_observation = np.log2(observation_temp)/np.log2(65536)
        return processed_observation.reshape(1,4,4)

# %%
def get_grids_next_step(grid):
        #Returns the next 4 states s' from the current state s
        
        grids_list = []
        
        for movement in range(4):
            grid_before = grid.copy()
            env1=Game2048Env()
            env1.set_board(grid_before)
            try:
                _= env1.move(movement) 
            except:
                pass
            grid_after =env1.get_board()
            env1.get_board()
            grids_list.append(grid_after)
            
        return grids_list

# %%
class DQN:
    def __init__(self,env):
        #Defining the hyperparameters for the model
        self.env=env.get_board()
        #The replay memory will be stored in a Deque
        self.memory=deque(maxlen=2000)
        self.gamma=0.90
        self.epsilon=1.0
        self.epsilon_min=0.01
        self.epsilon_decay=0.995
        self.learning_rate=0.005
        self.tau=0.125
        #We use 2 models to prevent Bootstrapping
        self.model=self.create_model()
        self.target_model=self.create_model()
        
        
    def create_model(self):
        model=Sequential()
        state_shape=4
                
        model.add(Flatten(input_shape=(4,4)))
        model.add(Dense(units=1024,activation="relu"))
        model.add(Dense(units=512,activation="relu"))
        model.add(Dense(units=256,activation="relu"))
        model.add(Dense(units=4))
        model.compile(loss="mean_squared_error",optimizer=Adam(lr=self.learning_rate))
        print(model.summary())
        return model
                  
    def act(self,state):
        #Epsilon value decays as model gains experience
        self.epsilon*=self.epsilon_decay
        self.epsilon=max(self.epsilon_min,self.epsilon)
        if np.random.random()<self.epsilon:
                  return np.random.randint(0,4)
        else:
            #Getting the 4 future states
            allstates=get_grids_next_step(state)
            
            res=[]
            for i in range(len(allstates)):
                if (allstates[i]==state).all():
                    res.append(0)
                else:
                    processed_state=process_log(allstates[i])
                    #max from the 4 future Q_Values is appended in res
                    res.append(np.max(self.model.predict(processed_state)))
            
            a=self.model.predict(process_log(state))
            #Final Q_Values are the sum of Q_Values of current state andfuture states
            final=np.add(a,res)
            
            return np.argmax(final)
    
    def remember(self, state, action, reward, new_state, done):
        #Replay Memory stores tuple(S, A, R, S')
        self.memory.append([state, action, reward, new_state, done])

    def replay(self):
        batch_size=32
        if len(self.memory)<batch_size:
            return
        samples=random.sample(self.memory,batch_size)
        for sample in samples:
            
            state,action,reward,new_state,done=sample
            
            target=self.target_model.predict(process_log(state))
            
            
            if done:
                target[0][action]=reward
            else:
                #Bellman Equation for update
                Q_future=max(self.target_model.predict(process_log(new_state))[0])
                
                #The move which was selected, its Q_Value gets updated
                target[0][action]=reward+Q_future*self.gamma
            self.model.fit((process_log(state)),target,epochs=1,verbose=0)
                  
                  
    def target_train(self):
        weights=self.model.get_weights()
        target_weights=self.target_model.get_weights()
        for i in range(len(target_weights)):
            target_weights[i]=weights[i]*self.tau+target_weights[i]*(1-self.tau)
        self.target_model.set_weights(target_weights)
                  
                  
    def save_model(self,fn):
        self.model.save(fn)

# %%
def main():
    env=Game2048Env()
    gamma=0.9
    epsilon=0.95
    
    trials=2000
    trial_len=500
    dqn_agent=DQN(env=env)
    steps=[]
    
    
    
    for trial in range(trials):
        env.reset()
        cur_state=env.get_board()
        
        cur_state=cur_state.reshape(4,4)
        stepno=0
        
        for step in range(trial_len):
            stepno+=1
            
            action=dqn_agent.act(cur_state)
            
            _,reward,done,_=env.step(action)
            new_state=env.get_board()
            
            dqn_agent.remember(cur_state,action,reward,new_state,done)
            if step%25==0:
                dqn_agent.replay()
                dqn_agent.target_train()
            
            cur_agent=new_state
            
            if done:
                
                break
        
        if stepno<500:
            
            if env.highest()==2048:
                print("Completed in --",trial)
                print(env.get_board())
                max_tile.append(env.highest())

                dqn_agent.save_model("success.model")

            
            else:
                print(f"Trial number {trial} Failed to complete in 500 steps")
                print(env.get_board())
                max_tile.append(env.highest())
                if env.highest()>=512:
                    dqn_agent.save_model("trial-{}.model".format(trial))
                    
        else:
            print(f"Failed to complete in 500 steps")
            print(env.get_board())
            max_tile.append(env.highest())

            
if __name__ == "__main__":
    main()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_5 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1024)              17408
# _________________________________________________________________
# dense_18 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 674,564
# Trainable params: 674,564
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 1024)              17408
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_23 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_24 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 674,564
# Trainable params: 674,564
# Non-trainable params: 0
# _________________________________________________________________
# None
# Trial number 0 Failed to complete in 500 steps
# [[ 4  8 64  2]
#  [ 2  4 32  8]
#  [ 8 64  8  4]
#  [ 2  8  4  2]]
# Trial number 1 Failed to complete in 500 steps
# [[  8   2  16   4]
#  [128  32   2  64]
#  [  8   2   8   4]
#  [  4  16   4   2]]
# Trial number 2 Failed to complete in 500 steps
# [[ 16   8   4   2]
#  [ 64 256  16   8]
#  [ 32   2  32  16]
#  [ 16   8   2   4]]
# Trial number 3 Failed to complete in 500 steps
# [[ 2 16  4  2]
#  [16  4 32 16]
#  [32 16  8  2]
#  [ 8  4  2  4]]
# Trial number 4 Failed to complete in 500 steps
# [[ 32   8   2  16]
#  [  2 128   4   8]
#  [ 64  16  32   4]
#  [ 16   4   8   2]]
# Trial number 5 Failed to complete in 500 steps
# [[  8 128  32   2]
#  [128  64  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 6 Failed to complete in 500 steps
# [[16  2 32 16]
#  [ 2 32 16  8]
#  [32 16  8  4]
#  [ 2  8  4  2]]
# Trial number 7 Failed to complete in 500 steps
# [[128   2   8  16]
#  [ 32  16   4   8]
#  [ 16   4   2   4]
#  [  4   2   4   2]]
# Trial number 8 Failed to complete in 500 steps
# [[  2 128  16   4]
#  [  8  64  32   8]
#  [128  32   8   4]
#  [ 64  16   4   2]]
# Trial number 9 Failed to complete in 500 steps
# [[  2   4  64   2]
#  [256  64  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 10 Failed to complete in 500 steps
# [[  2 128   4   2]
#  [  8  64  16   8]
#  [ 64  16   8   4]
#  [ 32   8   4   2]]
# Trial number 11 Failed to complete in 500 steps
# [[  2 128   8   4]
#  [128  64  16   2]
#  [ 64  16   8   4]
#  [  2   8   4   2]]
# Trial number 12 Failed to complete in 500 steps
# [[  4 128  32  16]
#  [128  32  16   8]
#  [  2  16   8   4]
#  [  4   2   4   2]]
# Trial number 13 Failed to complete in 500 steps
# [[ 32  16   4   2]
#  [128  32  16   4]
#  [ 64  16   8   2]
#  [ 32   8   2   4]]
# Trial number 14 Failed to complete in 500 steps
# [[  4  16   4   8]
#  [256  64  32   2]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 15 Failed to complete in 500 steps
# [[32  8  4  2]
#  [ 2 32 16  8]
#  [64 16  8  4]
#  [16  8  4  2]]
# Trial number 16 Failed to complete in 500 steps
# [[  8   2  32  16]
#  [128  32  16   8]
#  [ 64  16   8   2]
#  [  2   4   2   4]]
# Trial number 17 Failed to complete in 500 steps
# [[128  64   2  16]
#  [ 64  16   4   2]
#  [ 16   4   2   4]
#  [  4   2   4   2]]
# Trial number 18 Failed to complete in 500 steps
# [[ 2 32 16  8]
#  [64 16  8  4]
#  [32  8  4  2]
#  [16  4  2  4]]
# Trial number 19 Failed to complete in 500 steps
# [[  4  64  32   4]
#  [128   2  16   2]
#  [ 32  16   2   8]
#  [ 16   2   8   2]]
# Trial number 20 Failed to complete in 500 steps
# [[128   8  32   8]
#  [  8  64  16   2]
#  [  4  16   2   4]
#  [ 16   8   4   2]]
# Trial number 21 Failed to complete in 500 steps
# [[128   2  32   4]
#  [ 64   4   2   8]
#  [ 32   2   8   4]
#  [ 16   8   4   2]]
# Trial number 22 Failed to complete in 500 steps
# [[128   4  64   2]
#  [  4  64  32   4]
#  [ 64  16   8  16]
#  [ 16   4   2   4]]
# Trial number 23 Failed to complete in 500 steps
# [[256 128  64   2]
#  [128   4  32   4]
#  [ 32  16   8   2]
#  [ 16   8   2   4]]
# Trial number 24 Failed to complete in 500 steps
# [[  4 128   2  16]
#  [128  64  32   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 25 Failed to complete in 500 steps
# [[512   8   4   2]
#  [128  32   2  16]
#  [ 64  16  64   4]
#  [ 16   2   4   2]]
# Trial number 26 Failed to complete in 500 steps
# [[128  64  32   4]
#  [  2  32  16   8]
#  [ 64   2   8   2]
#  [ 16   8   2   4]]
# Trial number 27 Failed to complete in 500 steps
# [[ 32  64   8   2]
#  [256  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 28 Failed to complete in 500 steps
# [[128  64  32   2]
#  [ 64  32   2   4]
#  [  4  64  16   2]
#  [ 16   4   2   4]]
# Trial number 29 Failed to complete in 500 steps
# [[256 128  32   2]
#  [128  64  16   8]
#  [ 64  32   8   4]
#  [ 16   8   4   2]]
# Trial number 30 Failed to complete in 500 steps
# [[ 16 128  32   2]
#  [ 64  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 31 Failed to complete in 500 steps
# [[256  64  32   4]
#  [128   8   4   2]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 32 Failed to complete in 500 steps
# [[ 2 64  8  2]
#  [64 32 16  8]
#  [32  4  8  4]
#  [16  8  4  2]]
# Trial number 33 Failed to complete in 500 steps
# [[512   2  32   4]
#  [256  64  16   8]
#  [ 64  16   8   4]
#  [ 32   8   4   2]]
# Trial number 34 Failed to complete in 500 steps
# [[256   2  32   2]
#  [  2  64  16   8]
#  [ 64  32   8   4]
#  [ 32   8   4   2]]
# Trial number 35 Failed to complete in 500 steps
# [[128  64  16   2]
#  [ 64   4  32   4]
#  [ 32  16   8   2]
#  [ 16   8   2   4]]
# Trial number 36 Failed to complete in 500 steps
# [[  4 128  64  32]
#  [128  32  16   8]
#  [ 32  16   8   2]
#  [ 16   4   2   4]]
# Trial number 37 Failed to complete in 500 steps
# [[256   8   2   4]
#  [128  64  32   2]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 38 Failed to complete in 500 steps
# [[ 32   8   4   2]
#  [128  64  32  16]
#  [ 64  32  16   2]
#  [ 32   8   2   4]]
# Trial number 39 Failed to complete in 500 steps
# [[32 64 16  4]
#  [ 2  8  4  8]
#  [32  2  8  2]
#  [16  4  2  4]]
# Trial number 40 Failed to complete in 500 steps
# [[64  2  4  2]
#  [ 8  4  2  8]
#  [ 4 32  8  4]
#  [ 2  8  4  2]]
# Trial number 41 Failed to complete in 500 steps
# [[128  64  32   4]
#  [ 32   4  16   8]
#  [  4  32   8   4]
#  [  2  16   4   2]]
# Trial number 42 Failed to complete in 500 steps
# [[ 4 64  4 16]
#  [ 8  2 32  8]
#  [ 2 64 16  4]
#  [32 16  4  2]]
# Trial number 43 Failed to complete in 500 steps
# [[  2 128  32   2]
#  [128  32  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 44 Failed to complete in 500 steps
# [[256 128  16   2]
#  [  4   8   2   8]
#  [ 64   4  16   4]
#  [  8   2   4   2]]
# Trial number 45 Failed to complete in 500 steps
# [[  4 128   2   8]
#  [ 16  32  16   4]
#  [  4  16   8   2]
#  [  2   8   2   4]]
# Trial number 46 Failed to complete in 500 steps
# [[256  64  32   4]
#  [128  32  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 47 Failed to complete in 500 steps
# [[256 128   4   2]
#  [128  32  16   8]
#  [ 64  16   8   4]
#  [ 32   8   4   2]]
# Trial number 48 Failed to complete in 500 steps
# [[ 2 32  8  2]
#  [ 4 16  2  8]
#  [32  8 16  4]
#  [ 4  2  4  2]]
# Trial number 49 Failed to complete in 500 steps
# [[64 32 16  8]
#  [32 16  8  2]
#  [ 8  2 16  4]
#  [ 2 16  8  2]]
# Trial number 50 Failed to complete in 500 steps
# [[  8  64   2  16]
#  [128  16   8   2]
#  [ 16   2  32   8]
#  [  8   4   8   2]]
# Trial number 51 Failed to complete in 500 steps
# [[128   2  32   4]
#  [  2  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 52 Failed to complete in 500 steps
# [[  4   2  64   4]
#  [ 32 128   4   8]
#  [ 64  32   2   4]
#  [ 16   8   4   2]]
# Trial number 53 Failed to complete in 500 steps
# [[256  64  16   2]
#  [ 64  32   2   8]
#  [ 32   2   8   2]
#  [ 16   4   2   4]]
# Trial number 54 Failed to complete in 500 steps
# [[  2 256 128   2]
#  [  8   4  32   8]
#  [  4  32  16   4]
#  [  2  16   4   2]]
# Trial number 55 Failed to complete in 500 steps
# [[256  64   4   2]
#  [  4 128  32   8]
#  [128  32   8   4]
#  [ 64  16   4   2]]
# Trial number 56 Failed to complete in 500 steps
# [[128  32   4   2]
#  [  4 128  16   8]
#  [  2  32   8   4]
#  [ 32  16   4   2]]
# Trial number 57 Failed to complete in 500 steps
# [[256   4  16   4]
#  [ 32 128  32   8]
#  [  8  16   8   4]
#  [  4   2   4   2]]
# Trial number 58 Failed to complete in 500 steps
# [[128   2   4   2]
#  [ 64  32  64   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 59 Failed to complete in 500 steps
# [[64  2 32  4]
#  [32 16  8  2]
#  [16  8  4  8]
#  [ 8  4  2  4]]
# Trial number 60 Failed to complete in 500 steps
# [[128   8   4   2]
#  [  4  64  16   8]
#  [  2  16   8   4]
#  [ 16   8   4   2]]
# Trial number 61 Failed to complete in 500 steps
# [[256   4  32  16]
#  [  2 128  64   2]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 62 Failed to complete in 500 steps
# [[256  16   4   2]
#  [128  64  16   8]
#  [  2  32   8   4]
#  [ 16   8   4   2]]
# Trial number 63 Failed to complete in 500 steps
# [[128   4  64  16]
#  [ 64  32  16   8]
#  [  2   8  64   4]
#  [ 16   2   4   2]]
# Trial number 64 Failed to complete in 500 steps
# [[128   2  64   4]
#  [  4  64  16   2]
#  [  2  16   8   4]
#  [ 16   8   4   2]]
# Trial number 65 Failed to complete in 500 steps
# [[256   8  64   2]
#  [  2  64  32   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 66 Failed to complete in 500 steps
# [[256   2  64   2]
#  [  4  64   2   8]
#  [ 64  32   8   4]
#  [ 32  16   4   2]]
# Trial number 67 Failed to complete in 500 steps
# [[256 128   2  16]
#  [128  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 68 Failed to complete in 500 steps
# [[  8   2   8   2]
#  [256  32   2   8]
#  [ 64   8  16   2]
#  [ 32   2   8   4]]
# Trial number 69 Failed to complete in 500 steps
# [[ 32  16   4   2]
#  [128   4  64   8]
#  [ 32   2   8   4]
#  [ 16   8   4   2]]
# Trial number 70 Failed to complete in 500 steps
# [[256  64  16   4]
#  [  4  32   8   2]
#  [ 32 128  16   8]
#  [ 16   8   4   2]]
# Trial number 71 Failed to complete in 500 steps
# [[  4 256  32   2]
#  [ 64  32  16   8]
#  [ 32  16   8   4]
#  [  8   2   4   2]]
# Trial number 72 Failed to complete in 500 steps
# [[  2 256   2  32]
#  [128  64 128   2]
#  [  2  16  32   4]
#  [ 16   8   4   2]]
# Trial number 73 Failed to complete in 500 steps
# [[128   8  64   2]
#  [  4  64  16   8]
#  [  2  32   8   4]
#  [ 16   8   4   2]]
# Trial number 74 Failed to complete in 500 steps
# [[32  2 32 16]
#  [ 4 32 16  4]
#  [32 16  8  2]
#  [16  8  2  4]]
# Trial number 75 Failed to complete in 500 steps
# [[256  64  32   2]
#  [128  32   2   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 76 Failed to complete in 500 steps
# [[256 128  64  16]
#  [128   2  32   8]
#  [ 64  32  16   4]
#  [ 32  16   4   2]]
# Trial number 77 Failed to complete in 500 steps
# [[256   2  16   4]
#  [ 64  16   4   2]
#  [  2  32  16   4]
#  [ 16   8   4   2]]
# Trial number 78 Failed to complete in 500 steps
# [[ 32   8   4   2]
#  [128  64  16   8]
#  [  2  16   4   2]
#  [ 16   8   2   4]]
# Trial number 79 Failed to complete in 500 steps
# [[256 128  32   4]
#  [128  32  16   2]
#  [ 64  16   8  16]
#  [ 16   8   4   2]]
# Trial number 80 Failed to complete in 500 steps
# [[  8 128   8   4]
#  [128  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 81 Failed to complete in 500 steps
# [[ 16  64   4   2]
#  [128  32  16   8]
#  [ 64  16   8   2]
#  [  8   4   2   4]]
# Trial number 82 Failed to complete in 500 steps
# [[256   4  16   2]
#  [  2  32   4   8]
#  [ 16   4   2   4]
#  [  8   2   8   2]]
# Trial number 83 Failed to complete in 500 steps
# [[  4   2  32   4]
#  [256  32  16   8]
#  [ 64  16   8   4]
#  [ 32   8   4   2]]
# Trial number 84 Failed to complete in 500 steps
# [[64 16  2  4]
#  [16  8  4  2]
#  [ 8  4  2  4]
#  [16  2  8  2]]
# Trial number 85 Failed to complete in 500 steps
# [[64  4 64  2]
#  [ 2 64 32 16]
#  [64 32  4  8]
#  [32 16  2  4]]
# Trial number 86 Failed to complete in 500 steps
# [[64  4 32 16]
#  [ 2 32 16  8]
#  [32 16  8  4]
#  [ 2  8  4  2]]
# Trial number 87 Failed to complete in 500 steps
# [[64 16  4  2]
#  [32  2  8 16]
#  [16  8  2  4]
#  [ 4  2  4  2]]
# Trial number 88 Failed to complete in 500 steps
# [[128 256  32   2]
#  [  4 128  16   8]
#  [ 64  32   8   4]
#  [ 32   8   4   2]]
# Trial number 89 Failed to complete in 500 steps
# [[ 64 128  64   2]
#  [  2  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 90 Failed to complete in 500 steps
# [[128   8  16   2]
#  [  2  32   2   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 91 Failed to complete in 500 steps
# [[128   4  64   2]
#  [  4  64  32   4]
#  [ 64  16   4  16]
#  [ 16   4   2   4]]
# Trial number 92 Failed to complete in 500 steps
# [[128   4  32   8]
#  [ 32  16   4   2]
#  [ 16   8   2   4]
#  [  2  16   4   2]]
# Trial number 93 Failed to complete in 500 steps
# [[ 64   8   2  16]
#  [256  64  16   8]
#  [128  32   8   4]
#  [ 32  16   4   2]]
# Trial number 94 Failed to complete in 500 steps
# [[256  16   4   2]
#  [128  64  32   8]
#  [ 32  16   4   2]
#  [ 16   8   2   4]]
# Trial number 95 Failed to complete in 500 steps
# [[ 2 32 16  4]
#  [64 16 32  8]
#  [32  2  8  4]
#  [16  8  4  2]]
# Trial number 96 Failed to complete in 500 steps
# [[  4  64  32   4]
#  [128  16   8  16]
#  [ 32   8   2   4]
#  [  2  16   4   2]]
# Trial number 97 Failed to complete in 500 steps
# [[  2 128   4   2]
#  [128  32  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 98 Failed to complete in 500 steps
# [[128   4  16   8]
#  [ 16  64   8   4]
#  [  8  32   4   2]
#  [  4  16   8   4]]
# Trial number 99 Failed to complete in 500 steps
# [[64  8  4  2]
#  [ 4  2 32 16]
#  [64 32  8  4]
#  [ 4  8  4  2]]
# Trial number 100 Failed to complete in 500 steps
# [[256  32   8   2]
#  [128   2  32   8]
#  [  2 128  16   4]
#  [  4  16   4   2]]
# Trial number 101 Failed to complete in 500 steps
# [[ 2 32  8  2]
#  [32 16  2  8]
#  [ 8 32  8  4]
#  [ 4 16  4  2]]
# Trial number 102 Failed to complete in 500 steps
# [[64  8  4 16]
#  [ 8 32 16  8]
#  [32 16  8  4]
#  [16  8  4  2]]
# Trial number 103 Failed to complete in 500 steps
# [[ 64   4  64   2]
#  [ 32 128  16   4]
#  [  8  16   4   2]
#  [  2   4   2   4]]
# Trial number 104 Failed to complete in 500 steps
# [[512 128  32   2]
#  [  2  64  16   8]
#  [ 64  32   8   2]
#  [ 32  16   2   4]]
# Trial number 105 Failed to complete in 500 steps
# [[ 16   2   4  32]
#  [128  64  32   8]
#  [ 64   8   4   2]
#  [ 16   4   2   4]]
# Trial number 106 Failed to complete in 500 steps
# [[ 32   4   2  16]
#  [128   8  64   4]
#  [  4  32   4   2]
#  [  2   4   8   4]]
# Trial number 107 Failed to complete in 500 steps
# [[256   2  16   2]
#  [ 64  16   2   8]
#  [ 32   4  16   4]
#  [  8   2   8   2]]
# Trial number 108 Failed to complete in 500 steps
# [[  8 128  16   4]
#  [128  64  32  16]
#  [ 64  16   4   2]
#  [ 16   4   2   4]]
# Trial number 109 Failed to complete in 500 steps
# [[ 4  2  4 32]
#  [ 2 64 32  4]
#  [64 32 16  2]
#  [32  4  2  4]]
# Trial number 110 Failed to complete in 500 steps
# [[ 4 64 32  4]
#  [64 32  8 16]
#  [16  8  4  8]
#  [ 8  4  2  4]]
# Trial number 111 Failed to complete in 500 steps
# [[ 2 64 32  4]
#  [64 32  4  8]
#  [16  4  8  4]
#  [ 8  2  4  2]]
# Trial number 112 Failed to complete in 500 steps
# [[256  64   8   2]
#  [ 16   8  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 113 Failed to complete in 500 steps
# [[32  4  8  4]
#  [ 4 32  4  2]
#  [16  4  2 16]
#  [ 8  2  4  2]]
# Trial number 114 Failed to complete in 500 steps
# [[256 128   8   2]
#  [  2  64   2   8]
#  [128   2  16   2]
#  [ 32  16   2   4]]
# Trial number 115 Failed to complete in 500 steps
# [[256  16   4   2]
#  [  4 128  16   8]
#  [128  32   8   4]
#  [ 32  16   4   2]]
# Trial number 116 Failed to complete in 500 steps
# [[16  8 32  4]
#  [ 2 64 16  8]
#  [64 32  8  4]
#  [32 16  4  2]]
# Trial number 117 Failed to complete in 500 steps
# [[512  64   4   2]
#  [128   4  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 118 Failed to complete in 500 steps
# [[256 128   8   4]
#  [ 16  32   4   2]
#  [  2  16   2   4]
#  [  4   2   4   2]]
# Trial number 119 Failed to complete in 500 steps
# [[ 2 64 32  2]
#  [64 32  8 16]
#  [32  8  4  2]
#  [ 8  4  2  4]]
# Trial number 120 Failed to complete in 500 steps
# [[32 16  8 32]
#  [ 2 32 16  8]
#  [32 16  8  4]
#  [16  8  4  2]]
# Trial number 121 Failed to complete in 500 steps
# [[128  32   8   2]
#  [ 64   8   4   8]
#  [ 16   4   2   4]
#  [  8   2   4   2]]
# Trial number 122 Failed to complete in 500 steps
# [[512  16   2   4]
#  [ 64  32  16   8]
#  [ 32   4  32   4]
#  [  4   2   4   2]]
# Trial number 123 Failed to complete in 500 steps
# [[128   2  64  16]
#  [  4  64  32   8]
#  [ 64  16   4   2]
#  [ 32   4   2   4]]
# Trial number 124 Failed to complete in 500 steps
# [[128   2  16   2]
#  [ 32  16   8  16]
#  [ 16   8   2   4]
#  [  8   2   4   2]]
# Trial number 125 Failed to complete in 500 steps
# [[512  16   8   4]
#  [  8 128  32  16]
#  [ 64  32  16   2]
#  [ 16   4   2   4]]
# Trial number 126 Failed to complete in 500 steps
# [[  2 128   4   8]
#  [  4  64  32   4]
#  [ 64  32   4   2]
#  [ 16   2   8   4]]
# Trial number 127 Failed to complete in 500 steps
# [[ 32  64   2   8]
#  [  8 128  16   2]
#  [ 32  16  32   4]
#  [  8   2   8   2]]
# Trial number 128 Failed to complete in 500 steps
# [[  8 128   2  16]
#  [256  64  32   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 129 Failed to complete in 500 steps
# [[256  64   2  16]
#  [ 16   2  16   8]
#  [  2   8  32   4]
#  [  8   2   8   2]]
# Trial number 130 Failed to complete in 500 steps
# [[  8 128  64   4]
#  [256  64   4   2]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 131 Failed to complete in 500 steps
# [[128   8   2  16]
#  [  4  16  32   8]
#  [ 16   8   4   2]
#  [  8   4   2   4]]
# Trial number 132 Failed to complete in 500 steps
# [[  8 128   4   2]
#  [128  32  16   8]
#  [ 64  16   4   2]
#  [ 32   4   2   4]]
# Trial number 133 Failed to complete in 500 steps
# [[ 16   2   8   2]
#  [256  32  16   8]
#  [ 64  16  64   4]
#  [ 16   4   8   2]]
# Trial number 134 Failed to complete in 500 steps
# [[64 32  8  2]
#  [16  4 16  8]
#  [ 4  8  4  2]
#  [ 8  4  2  4]]
# Trial number 135 Failed to complete in 500 steps
# [[128  64  32   2]
#  [ 64  32   8  16]
#  [ 16   8   4   2]
#  [  8   4   2   8]]
# Trial number 136 Failed to complete in 500 steps
# [[128   4  16   2]
#  [ 16  64   2   8]
#  [  4   2   8   2]
#  [  8   4   2   4]]
# Trial number 137 Failed to complete in 500 steps
# [[128 256  64   2]
#  [  2  64  32  16]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 138 Failed to complete in 500 steps
# [[  8 128  16   4]
#  [  2  64  32   8]
#  [ 32  16   8   4]
#  [  2   8   4   2]]
# Trial number 139 Failed to complete in 500 steps
# [[128   4  64  16]
#  [  2  64  16   4]
#  [  4  16   4   2]
#  [  2   8   2   4]]
# Trial number 140 Failed to complete in 500 steps
# [[  4 256   8   2]
#  [256 128  32   8]
#  [  2  32   8   4]
#  [ 32   8   4   2]]
# Trial number 141 Failed to complete in 500 steps
# [[256  32   8   2]
#  [  4  64  32   8]
#  [ 64  32   8   4]
#  [ 16   8   4   2]]
# Trial number 142 Failed to complete in 500 steps
# [[256  64   2  16]
#  [ 64  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 143 Failed to complete in 500 steps
# [[  4  64  32   2]
#  [128  32  16   8]
#  [ 64  16   8   4]
#  [ 32   8   4   2]]
# Trial number 144 Failed to complete in 500 steps
# [[128  32   8   2]
#  [ 64   8  16   8]
#  [  4   2   8   4]
#  [  2   8   4   2]]
# Trial number 145 Failed to complete in 500 steps
# [[256 128  64   2]
#  [ 16  32  16   8]
#  [  2  16   8   4]
#  [ 16   8   4   2]]
# Trial number 146 Failed to complete in 500 steps
# [[256   2  16   2]
#  [  2 128  32   8]
#  [ 64  16   8   2]
#  [  2   4   2   4]]
# Trial number 147 Failed to complete in 500 steps
# [[256 128   2  16]
#  [  2  64  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 148 Failed to complete in 500 steps
# [[128  16   8   2]
#  [ 32   8   2   8]
#  [  8  16  32   4]
#  [  4   2   4   2]]
# Trial number 149 Failed to complete in 500 steps
# [[512   8  32  16]
#  [ 64  32  16   8]
#  [ 16   8   4   2]
#  [  8   4   2   4]]
# Trial number 150 Failed to complete in 500 steps
# [[256  32   2   4]
#  [128   2   8   2]
#  [ 32   8  64   4]
#  [  4   2   8   2]]
# Trial number 151 Failed to complete in 500 steps
# [[  4 128  64   2]
#  [256  32  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 152 Failed to complete in 500 steps
# [[ 16   8  32  16]
#  [256 128  16   4]
#  [  2  64   8   2]
#  [ 16   8   2   4]]
# Trial number 153 Failed to complete in 500 steps
# [[256 128   4  16]
#  [  4  64  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 154 Failed to complete in 500 steps
# [[256  64   8   2]
#  [128   2  32  16]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 155 Failed to complete in 500 steps
# [[128  16   4   2]
#  [ 16   2  16   8]
#  [ 64  16   8   4]
#  [  2   8   4   2]]
# Trial number 156 Failed to complete in 500 steps
# [[ 4  2  8  4]
#  [64 16 32  2]
#  [32  2 16  4]
#  [ 8 16  8  2]]
# Trial number 157 Failed to complete in 500 steps
# [[128  16  32   2]
#  [ 64   4   8   4]
#  [ 16   8   4   2]
#  [  8   4   2   4]]
# Trial number 158 Failed to complete in 500 steps
# [[256 128  32   2]
#  [ 64  32   8   4]
#  [  4  64   4   2]
#  [  8   4   2   4]]
# Trial number 159 Failed to complete in 500 steps
# [[256  64   2  16]
#  [ 64   8  32   8]
#  [ 32   2  16   4]
#  [  2  16   4   2]]
# Trial number 160 Failed to complete in 500 steps
# [[64 16  8  4]
#  [ 2 64  4  2]
#  [32 16  8  4]
#  [16  8  4  2]]
# Trial number 161 Failed to complete in 500 steps
# [[ 64   2  64  32]
#  [128  64  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 162 Failed to complete in 500 steps
# [[128  32   8   2]
#  [ 64   2  32   8]
#  [  8  64  16   4]
#  [ 32  16   4   2]]
# Trial number 163 Failed to complete in 500 steps
# [[16  8  4  2]
#  [64 32 16  8]
#  [32 16  8  4]
#  [16  8  4  2]]
# Trial number 164 Failed to complete in 500 steps
# [[256 128  16   2]
#  [128  64  32   8]
#  [ 64  32  16   4]
#  [ 32  16   8   2]]
# Trial number 165 Failed to complete in 500 steps
# [[128   8   4   2]
#  [ 64  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 166 Failed to complete in 500 steps
# [[  4 128   4  16]
#  [ 64  32   2   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 167 Failed to complete in 500 steps
# [[  2 128   4   8]
#  [  4  64  32   2]
#  [128  16   4   8]
#  [ 16   8   2   4]]
# Trial number 168 Failed to complete in 500 steps
# [[128  64   2  32]
#  [ 64  16   8   2]
#  [ 16   8  32   4]
#  [  8   2   4   2]]
# Trial number 169 Failed to complete in 500 steps
# [[256  64  32   4]
#  [ 64  32  16   8]
#  [ 32  16   8   4]
#  [ 16   8   4   2]]
# Trial number 170 Failed to complete in 500 steps
# [[512 128   8   2]
#  [128  64  32  16]
#  [ 64  16   8   4]
#  [ 32   2   4   2]]
# Trial number 171 Failed to complete in 500 steps
# [[256   8  16   2]
#  [ 64  32   8  16]
#  [ 32  16   4   8]
#  [ 16   8   2   4]]
# Trial number 172 Failed to complete in 500 steps
# [[256  64   8   4]
#  [128   8  16   2]
#  [ 16   4   8   4]
#  [  8  16   4   2]]
# Trial number 173 Failed to complete in 500 steps
# [[  4  64   8   2]
#  [256  32  16   4]
#  [128  16   8   2]
#  [ 32   4   2   4]]
# Trial number 174 Failed to complete in 500 steps
# [[64  2 64  2]
#  [ 8 64 16  8]
#  [ 2 32  8  4]
#  [32  8  4  2]]
# Trial number 175 Failed to complete in 500 steps
# [[16  8  4  2]
#  [ 2 64 32  8]
#  [64 16  8  4]
#  [16  8  4  2]]
# Trial number 176 Failed to complete in 500 steps
# [[256 128  32   4]
#  [128   8  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 177 Failed to complete in 500 steps
# [[ 2 64  4  2]
#  [64  8  2  8]
#  [32  4 16  4]
#  [16  8  4  2]]
# Trial number 178 Failed to complete in 500 steps
# [[ 32   2  64   4]
#  [256  64  32   8]
#  [ 64  32   8   4]
#  [ 32  16   4   2]]
# Trial number 179 Failed to complete in 500 steps
# [[128   4  32  16]
#  [  2 128  16   2]
#  [ 16  32   8   4]
#  [  4   8   4   2]]
# Trial number 180 Failed to complete in 500 steps
# [[256   4  64  32]
#  [128  32  16   8]
#  [  2  16   8   2]
#  [ 32   4   2   4]]
# Trial number 181 Failed to complete in 500 steps
# [[256   4  64  16]
#  [  2  64  16   8]
#  [ 16  32   4   2]
#  [  2   8   2   4]]
# Trial number 182 Failed to complete in 500 steps
# [[  2 128  32   2]
#  [256  32  16   8]
#  [128  16   8   4]
#  [ 32   8   4   2]]
# Trial number 183 Failed to complete in 500 steps
# [[  4 128  16   8]
#  [128   2   8   4]
#  [ 32  16   4   2]
#  [  8   4   2   4]]
# Trial number 184 Failed to complete in 500 steps
# [[64  8 32 16]
#  [ 2 64 16  8]
#  [64 32  8  4]
#  [32  8  4  2]]
# Trial number 185 Failed to complete in 500 steps
# [[256   4  64   2]
#  [ 32   2  16   8]
#  [  4  16   2   4]
#  [ 16   8   4   2]]
# Trial number 186 Failed to complete in 500 steps
# [[  4 128   2   4]
#  [  2  16   8  16]
#  [ 16   8  32   4]
#  [  8   2   8   2]]
# Trial number 187 Failed to complete in 500 steps
# [[  2   8   4  16]
#  [128  64  32   8]
#  [  2  32  16   2]
#  [ 32  16   8   4]]
# Trial number 188 Failed to complete in 500 steps
# [[256 128   2   4]
#  [128  64  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 189 Failed to complete in 500 steps
# [[ 2 64 16  2]
#  [64 16  8  4]
#  [32  8 32  2]
#  [16  4  2  4]]
# Trial number 190 Failed to complete in 500 steps
# [[256   4  32   2]
#  [ 64  16   2   4]
#  [ 16   8   4   2]
#  [  2  16   2   4]]
# Trial number 191 Failed to complete in 500 steps
# [[256  16   2   8]
#  [  8 128   4   2]
#  [ 16   4  16   4]
#  [ 32   2   8   2]]
# Trial number 192 Failed to complete in 500 steps
# [[128  64   2   4]
#  [  2   8  16   8]
#  [ 64   2   8   2]
#  [ 16   8   2   4]]
# Trial number 193 Failed to complete in 500 steps
# [[256   4  64   2]
#  [128  32  16   8]
#  [ 64  16   8   2]
#  [  8   4   2   4]]
# Trial number 194 Failed to complete in 500 steps
# [[ 16   2  16   8]
#  [128  16  32   4]
#  [ 64  32  16   2]
#  [  2   8   2   4]]
# Trial number 195 Failed to complete in 500 steps
# [[256   4  64   2]
#  [ 64   2  16   8]
#  [  4  64   8   4]
#  [  2  16   4   2]]
# Trial number 196 Failed to complete in 500 steps
# [[64 32  4  2]
#  [32  8 16  8]
#  [ 8  4  2  4]
#  [ 4  2  8  2]]
# Trial number 197 Failed to complete in 500 steps
# [[  4 256   2  32]
#  [  2 128  32  16]
#  [ 64  32   8   4]
#  [ 32   2   4   2]]
# Trial number 198 Failed to complete in 500 steps
# [[256 128  32   4]
#  [128  64   4   2]
#  [ 64  16   8  16]
#  [  8   4   2   4]]
# Trial number 199 Failed to complete in 500 steps
# [[128  32   8   4]
#  [ 16   8  32   8]
#  [  2  64  16   4]
#  [ 32  16   8   2]]
# Trial number 200 Failed to complete in 500 steps
# [[ 64   8   2   4]
#  [256  32  16   8]
#  [ 64  16   8   4]
#  [ 32   2   4   2]]
# Trial number 201 Failed to complete in 500 steps
# [[256   8   4   2]
#  [ 64  32  16   4]
#  [ 32  16   8   2]
#  [ 16   4   2   4]]
# Trial number 202 Failed to complete in 500 steps
# [[256   4  16   2]
#  [128  64  32   8]
#  [ 64  32  16   4]
#  [ 16   8   4   2]]
# Trial number 203 Failed to complete in 500 steps
# [[  2 128  32   8]
#  [128  64  16   4]
#  [ 64   2   4   2]
#  [ 32   8   2   4]]
# Trial number 204 Failed to complete in 500 steps
# [[64 16  4 16]
#  [ 8 64 32  8]
#  [64 32 16  4]
#  [32 16  8  2]]
# Trial number 205 Failed to complete in 500 steps
# [[256 128  32   8]
#  [128  32   8   2]
#  [  4   2  16   4]
#  [ 16   8   4   2]]
# Trial number 206 Failed to complete in 500 steps
# [[ 8 64  8  2]
#  [ 2 32 16  8]
#  [32 16  8  4]
#  [16  8  4  2]]
# Trial number 207 Failed to complete in 500 steps
# [[128   2  16   2]
#  [ 64   8   2   8]
#  [  4   2   8   2]
#  [ 16   4   2   4]]
# Trial number 208 Failed to complete in 500 steps
# [[256  32   8  32]
#  [128  64  16   8]
#  [ 64   8  32   2]
#  [ 16   2   8   4]]
# Trial number 209 Failed to complete in 500 steps
# [[256  16   4   2]
#  [ 64  32   8  16]
#  [ 32   8  16   2]
#  [  8   4   2   8]]
# Trial number 210 Failed to complete in 500 steps
# [[128  16   8  16]
#  [  8   2  16   8]
#  [ 64  32   2   4]
#  [ 16   8   4   2]]
# Trial number 211 Failed to complete in 500 steps
# [[32 16  2  4]
#  [16 32 16  8]
#  [32 16  8  2]
#  [16  4  2  4]]
# Trial number 212 Failed to complete in 500 steps
# [[128  64   4   2]
#  [ 64   2  32   8]
#  [ 32   8   4   2]
#  [ 16   2   8   4]]
# Trial number 213 Failed to complete in 500 steps
# [[64 16  4  2]
#  [ 8  2 16  8]
#  [64 16  8  4]
#  [16  8  4  2]]
# Trial number 214 Failed to complete in 500 steps
# [[  2  64   2  32]
#  [128  32  16   2]
#  [ 32   8   2   4]
#  [ 16   2  16   2]]
# Trial number 215 Failed to complete in 500 steps
# [[  4  32   8   2]
#  [128   8   2  16]
#  [ 32   2  16   4]
#  [ 16   8   4   2]]
# Trial number 216 Failed to complete in 500 steps
# [[16  4 32  2]
#  [64 32 16  8]
#  [32  2  8  4]
#  [16  8  4  2]]
# Trial number 217 Failed to complete in 500 steps
# [[256   8   2   4]
#  [  4 128  32   2]
#  [128   8  16   8]
#  [  8   4   2   4]]
# Trial number 218 Failed to complete in 500 steps
# [[ 32  16   2  16]
#  [128  64  16   8]
#  [  2  16   8   4]
#  [ 16   8   4   2]]
# Trial number 219 Failed to complete in 500 steps
# [[128  32   2  32]
#  [ 64   2  16   2]
#  [ 16   8  32   8]
#  [  8   2   8   2]]
# Trial number 220 Failed to complete in 500 steps
# [[128  16   4   2]
#  [  8  32  16   8]
#  [ 64  16   8   4]
#  [ 16   8   4   2]]
# Trial number 221 Failed to complete in 500 steps
# [[  2 128  32   2]
#  [128  64  16   8]
#  [ 64  16   8   4]
#  [ 32   8   4   2]]
