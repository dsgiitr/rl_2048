# %%
import gym
from gym import spaces
from gym.utils import seeding
import itertools
import logging
import numpy as np
from collections import deque
import itertools

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.optimizers import Adam
from keras import layers

# %%
#Importing the Game Board
from Game_Board import*
max_tile=[]

# %%
#Converting observations in range (0,1) using log(n)/log(max) so that gradients don't vanish
def process_log(observation):
        observation = np.reshape(observation, (4, 4))
        observation_temp = np.where(observation <= 0, 1, observation) 
        processed_observation = np.log2(observation_temp)/np.log2(65536)
        return processed_observation.reshape(1,4,4)

# %%
def get_grids_next_step(grid):
        #Returns the next 4 states s' from the current state s
        
        grids_list = []
        
        for movement in range(4):
            grid_before = grid.copy()
            env1=Game2048Env()
            env1.set_board(grid_before)
            try:
                _= env1.move(movement) 
            except:
                pass
            grid_after =env1.get_board()
            env1.get_board()
            grids_list.append(grid_after)
            
        return grids_list

# %%
class DQN:
    def __init__(self,env):
        #Defining the hyperparameters for the model
        self.env=env.get_board()
        #The replay memory will be stored in a Deque
        self.memory=deque(maxlen=2000)
        self.gamma=0.90
        self.epsilon=1.0
        self.epsilon_min=0.01
        self.epsilon_decay=0.995
        self.learning_rate=0.005
        self.tau=0.125
        #We use 2 models to prevent Bootstrapping
        self.model=self.create_model()
        self.target_model=self.create_model()
        
        
    def create_model(self):
        model=Sequential()
        state_shape=4
                
        model.add(Flatten(input_shape=(4,4)))
        model.add(Dense(units=1024,activation="relu"))
        model.add(Dense(units=512,activation="relu"))
        model.add(Dense(units=256,activation="relu"))
        model.add(Dense(units=4))
        model.compile(loss="mean_squared_error",optimizer=Adam(lr=self.learning_rate))
        print(model.summary())
        return model
                  
    def act(self,state):
        #Epsilon value decays as model gains experience
        self.epsilon*=self.epsilon_decay
        self.epsilon=max(self.epsilon_min,self.epsilon)
        if np.random.random()<self.epsilon:
                  return np.random.randint(0,4)
        else:
            #Getting the 4 future states
            allstates=get_grids_next_step(state)
            
            res=[]
            for i in range(len(allstates)):
                if (allstates[i]==state).all():
                    res.append(0)
                else:
                    processed_state=process_log(allstates[i])
                    #max from the 4 future Q_Values is appended in res
                    res.append(np.max(self.model.predict(processed_state)))
            
            a=self.model.predict(process_log(state))
            #Final Q_Values are the sum of Q_Values of current state andfuture states
            final=np.add(a,res)
            
            return np.argmax(final)
    
    def remember(self, state, action, reward, new_state, done):
        #Replay Memory stores tuple(S, A, R, S')
        self.memory.append([state, action, reward, new_state, done])

    def replay(self):
        batch_size=32
        if len(self.memory)<batch_size:
            return
        samples=random.sample(self.memory,batch_size)
        for sample in samples:
            
            state,action,reward,new_state,done=sample
            
            target=self.target_model.predict(process_log(state))
            
            
            if done:
                target[0][action]=reward
            else:
                #Bellman Equation for update
                Q_future=max(self.target_model.predict(process_log(new_state))[0])
                
                #The move which was selected, its Q_Value gets updated
                target[0][action]=reward+Q_future*self.gamma
            self.model.fit((process_log(state)),target,epochs=1,verbose=0)
                  
                  
    def target_train(self):
        weights=self.model.get_weights()
        target_weights=self.target_model.get_weights()
        for i in range(len(target_weights)):
            target_weights[i]=weights[i]*self.tau+target_weights[i]*(1-self.tau)
        self.target_model.set_weights(target_weights)
                  
                  
    def save_model(self,fn):
        self.model.save(fn)

# %%
def main():
    env=Game2048Env()
    gamma=0.9
    epsilon=0.95
    
    trials=2000
    trial_len=500
    dqn_agent=DQN(env=env)
    steps=[]
    
    
    
    for trial in range(trials):
        env.reset()
        cur_state=env.get_board()
        
        cur_state=cur_state.reshape(4,4)
        stepno=0
        
        for step in range(trial_len):
            stepno+=1
            
            action=dqn_agent.act(cur_state)
            
            _,reward,done,_=env.step(action)
            new_state=env.get_board()
            
            dqn_agent.remember(cur_state,action,reward,new_state,done)
            if step%10==0:
                dqn_agent.replay()
                dqn_agent.target_train()
            
            cur_agent=new_state
            
            if done:
                
                break
        
        if stepno<500:
            
            if env.highest()==2048:
                print("Completed in --",trial)
                print(env.get_board())
                max_tile.append(env.highest())

                dqn_agent.save_model("success.model")

            
            else:
                print(f"Trial number {trial} Failed to complete in 500 steps")
                print(env.get_board())
                max_tile.append(env.highest())
                if env.highest()>=512:
                    dqn_agent.save_model("trial-{}.model".format(trial))
                    
        else:
            print(f"Failed to complete in 500 steps")
            print(env.get_board())
            max_tile.append(env.highest())

            
if __name__ == "__main__":
    main()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              17408
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 674,564
# Trainable params: 674,564
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 16)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              17408
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_16 (Dense)             (None, 4)                 1028
# =================================================================
# Total params: 674,564
# Trainable params: 674,564
# Non-trainable params: 0
# _________________________________________________________________
# None
# Failed to complete in trial number 0 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16   4]
#  [  8  16 128  32]
#  [  2   4  16   4]]
# Failed to complete in trial number 1 in 500 steps
# [[ 2 16  2  4]
#  [ 4  8 16 64]
#  [ 8 16 32  4]
#  [ 2  8  4  2]]
# Failed to complete in trial number 2 in 500 steps
# [[ 4  8 16 32]
#  [ 2 32  8  4]
#  [ 8 16 64 32]
#  [ 2  8 16  2]]
# Failed to complete in trial number 3 in 500 steps
# [[ 2  8 32  4]
#  [ 4 32 64 16]
#  [ 2  8  2  8]
#  [ 4  2  4  2]]
# Failed to complete in trial number 4 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32  64]
#  [  8  32 256   2]
#  [  2   4   8 256]]
# Failed to complete in trial number 5 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [  2   4  16  64]]
# Failed to complete in trial number 6 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8   2  32  64]
#  [  2   4  16 128]]
# Failed to complete in trial number 7 in 500 steps
# [[  2   4   8  32]
#  [  4   8  32  64]
#  [  8  16  64   4]
#  [  2   8  32 128]]
# Failed to complete in trial number 8 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 9 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16  64   4]
#  [  2  32 128 256]]
# Failed to complete in trial number 10 in 500 steps
# [[  2   4   2   8]
#  [  4   2   4  16]
#  [  2   8  16   4]
#  [  4  16  32 128]]
# Failed to complete in trial number 11 in 500 steps
# [[  2   4  16  32]
#  [  4  32   2   8]
#  [ 16   8  32  64]
#  [  2   4   8 128]]
# Failed to complete in trial number 12 in 500 steps
# [[ 2  4 16  2]
#  [ 4  8  2  8]
#  [ 8 16 32 16]
#  [ 2  4 16 64]]
# Failed to complete in trial number 13 in 500 steps
# [[  2   4   8  16]
#  [  4   2  16  32]
#  [  8  16  32   4]
#  [  2   4  64 256]]
# Failed to complete in trial number 14 in 500 steps
# [[  2   4   2   8]
#  [  4   2   4  32]
#  [  8   4   8  64]
#  [  2   8  64 256]]
# Failed to complete in trial number 15 in 500 steps
# [[ 2  8  2 16]
#  [ 4 16 32 64]
#  [ 2 32 64  2]
#  [ 8  4  8 64]]
# Failed to complete in trial number 16 in 500 steps
# [[  2   4   2   8]
#  [  4   2   8  32]
#  [ 16   4  32 128]
#  [  2  64 128   4]]
# Failed to complete in trial number 17 in 500 steps
# [[  2   4   8  16]
#  [  4  16   4  64]
#  [  8  32  16 128]
#  [  2   8  32   2]]
# Failed to complete in trial number 18 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  32  64 128]
#  [  2   4  16 256]]
# Failed to complete in trial number 19 in 500 steps
# [[  4   2   4  16]
#  [  2   8  16  32]
#  [  4  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 20 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32  64]
#  [ 16  64 128   2]
#  [  2  32   4  32]]
# Failed to complete in trial number 21 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  8  32   4 256]
#  [  2  64 256   4]]
# Failed to complete in trial number 22 in 500 steps
# [[  2   4   8  16]
#  [  4   2  16  32]
#  [  2   4  64   8]
#  [  4  16 128 256]]
# Failed to complete in trial number 23 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16  64   4]
#  [  4  32   2 128]]
# Failed to complete in trial number 24 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  4   2   4 128]]
# Failed to complete in trial number 25 in 500 steps
# [[  2   8  16   2]
#  [  4  16   8  32]
#  [  2   4  32   4]
#  [  8  32   8 256]]
# Failed to complete in trial number 26 in 500 steps
# [[  2   4  16  32]
#  [  4   8  32  64]
#  [  2  32  64 256]
#  [  8  64 128   2]]
# Failed to complete in trial number 27 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16   2]
#  [  8  16  64   8]
#  [  2   8  16 128]]
# Failed to complete in trial number 28 in 500 steps
# [[  2   4   2   8]
#  [  4   8   4  16]
#  [  8  32  16  64]
#  [  2   4  64 128]]
# Failed to complete in trial number 29 in 500 steps
# [[  4   2   8  16]
#  [  2   8  16  64]
#  [  8   2  64 128]
#  [  4  32 128   2]]
# Failed to complete in trial number 30 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  32   2  64]
#  [  4   8  32 128]]
# Failed to complete in trial number 31 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [ 16  64  32  16]
#  [  2   4   8 256]]
# Failed to complete in trial number 32 in 500 steps
# [[ 2  4  8 32]
#  [ 4 16 32  2]
#  [ 8 32  4 16]
#  [ 4  8 32 64]]
# Failed to complete in trial number 33 in 500 steps
# [[ 2  4 16  2]
#  [ 4  8 32 64]
#  [ 8 32 64  2]
#  [ 2 16 32  8]]
# Failed to complete in trial number 34 in 500 steps
# [[  2   8   2  16]
#  [  8 128  16  32]
#  [ 16   8   2 128]
#  [  4   2  16 256]]
# Failed to complete in trial number 35 in 500 steps
# [[  2   4   2  32]
#  [  4   8  32  64]
#  [ 16  32  64 128]
#  [  2  64   2   8]]
# Failed to complete in trial number 36 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  2  16  64 128]
#  [ 16   2 128   4]]
# Failed to complete in trial number 37 in 500 steps
# [[  4   2   8  32]
#  [ 16   8  16  64]
#  [  4  32  64   2]
#  [  2   4   8 256]]
# Failed to complete in trial number 38 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32  64]
#  [  8  16  64 128]
#  [  2  32   2 256]]
# Failed to complete in trial number 39 in 500 steps
# [[  2   4   8  16]
#  [  4   2  16  32]
#  [  2  16  64 128]
#  [  8  64   2 256]]
# Failed to complete in trial number 40 in 500 steps
# [[  4   2   4   8]
#  [  2   4   8  16]
#  [  8  16  32  64]
#  [ 16  32   2 256]]
# Failed to complete in trial number 41 in 500 steps
# [[ 8  2  8 16]
#  [ 2  4 16 32]
#  [ 4 16 32 64]
#  [ 2 32 64  4]]
# Failed to complete in trial number 42 in 500 steps
# [[  8   2   4  16]
#  [  2   4  16  32]
#  [ 16   8  32 128]
#  [  2  32 128   2]]
# Failed to complete in trial number 43 in 500 steps
# [[  2   8  16  32]
#  [  8  16  32  64]
#  [ 16  32  64 128]
#  [  2  64 128   2]]
# Failed to complete in trial number 44 in 500 steps
# [[  2   8   2  16]
#  [  8   2  16  32]
#  [  2   8  32 128]
#  [  8  16  64   2]]
# Failed to complete in trial number 45 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8   4  32  64]
#  [ 32   2  64 128]]
# Failed to complete in trial number 46 in 500 steps
# [[  4   2   8  16]
#  [  2   8  16  32]
#  [  4  64  32  64]
#  [ 16   2   4 128]]
# Failed to complete in trial number 47 in 500 steps
# [[ 2  8  2 16]
#  [ 8  4  8 64]
#  [16 32 64  8]
#  [ 2  4  8 16]]
# Failed to complete in trial number 48 in 500 steps
# [[  4   2   8  16]
#  [  2   8  16  32]
#  [  8  16  32  64]
#  [  2  32   2 256]]
# Failed to complete in trial number 49 in 500 steps
# [[  4   2   4  16]
#  [  2   4   8  64]
#  [  4  32  64   2]
#  [  8  16 128 256]]
# Failed to complete in trial number 50 in 500 steps
# [[  2   8   2   4]
#  [  4  16   8  32]
#  [  2  32   4  64]
#  [  4  16  64 128]]
# Failed to complete in trial number 51 in 500 steps
# [[  2   4   2  16]
#  [  4   8  16  64]
#  [  8  16  64 128]
#  [  2   4   8 256]]
# Failed to complete in trial number 52 in 500 steps
# [[  2   4  16  32]
#  [  4  16  64   2]
#  [ 16   8 128 256]
#  [  2   4   8  32]]
# Failed to complete in trial number 53 in 500 steps
# [[  4   2   4  16]
#  [  2   8   2  64]
#  [  4  32   4 128]
#  [  2  16  64 256]]
# Failed to complete in trial number 54 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  8  16 128   2]
#  [  2  32  16 128]]
# Failed to complete in trial number 55 in 500 steps
# [[  4   2   4  32]
#  [  2   4  16   4]
#  [  4   8   2 128]
#  [  2  32  64 256]]
# Failed to complete in trial number 56 in 500 steps
# [[  2   4   8   2]
#  [  4   8   2  32]
#  [  8  32  16 256]
#  [ 16   4  64   4]]
# Failed to complete in trial number 57 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 32]
#  [ 8 16 32 64]
#  [ 2 32 64  4]]
# Failed to complete in trial number 58 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32  64]
#  [  8  32  64 128]
#  [  2  16   2 256]]
# Failed to complete in trial number 59 in 500 steps
# [[  2   4   2   4]
#  [  4   2   4  16]
#  [  2   4  16  32]
#  [  4   8  32 128]]
# Failed to complete in trial number 60 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  4  32  64 128]]
# Failed to complete in trial number 61 in 500 steps
# [[  4   2   4   8]
#  [  2   4  16   2]
#  [ 32   8  32  64]
#  [  2   4  64 128]]
# Failed to complete in trial number 62 in 500 steps
# [[ 4  2  4 16]
#  [ 2  8 16 32]
#  [ 4 16 64  8]
#  [32 64  4 64]]
# Failed to complete in trial number 63 in 500 steps
# [[  4   2   8  16]
#  [  2   8  16  32]
#  [  4  16  32  64]
#  [ 16   2  64 128]]
# Failed to complete in trial number 64 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2   4  64 512]]
# Failed to complete in trial number 65 in 500 steps
# [[  2   4   8  16]
#  [  4   2  16  32]
#  [  8   4   8 128]
#  [  2  16  64 256]]
# Failed to complete in trial number 66 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32  64]
#  [ 16  32  64 128]
#  [  2  64 128   4]]
# Failed to complete in trial number 67 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 32]
#  [ 8 16 32  2]
#  [ 2 64  2 16]]
# Failed to complete in trial number 68 in 500 steps
# [[  4   2   8   2]
#  [  2  16   2  64]
#  [  8   4  32 128]
#  [  2  16  64 256]]
# Failed to complete in trial number 69 in 500 steps
# [[  4   2   8  32]
#  [  2   8  32 128]
#  [  4  16  64   2]
#  [ 16  32   4 256]]
# Failed to complete in trial number 70 in 500 steps
# [[ 2  4 16 32]
#  [ 4  8 32 64]
#  [ 8 32 64  8]
#  [ 4 64  2 64]]
# Failed to complete in trial number 71 in 500 steps
# [[  4   2   8  16]
#  [  2   8   2  64]
#  [  8  32   4 128]
#  [  2   8  64   2]]
# Failed to complete in trial number 72 in 500 steps
# [[  2   4  16   2]
#  [  4   8  32   8]
#  [  2   4   2  32]
#  [  4  32  64 256]]
# Failed to complete in trial number 73 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  64   2 256]]
# Failed to complete in trial number 74 in 500 steps
# [[  8   2   8  32]
#  [ 16   4  32  64]
#  [  2  32 128   4]
#  [  4   8  32   2]]
# Failed to complete in trial number 75 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [  8  32 128   2]
#  [ 16   2  16 256]]
# Failed to complete in trial number 76 in 500 steps
# [[  4   8   2   8]
#  [  2   4   8  16]
#  [  4   8  16  64]
#  [  2  16  64 128]]
# Failed to complete in trial number 77 in 500 steps
# [[  2   4   8  16]
#  [  4   8   2  32]
#  [  8  16  32 128]
#  [  4  32 128 256]]
# Failed to complete in trial number 78 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [  2  32  64 256]]
# Failed to complete in trial number 79 in 500 steps
# [[  2   4  16   2]
#  [  4  16  32   4]
#  [  8  32   2  64]
#  [  4  16  64 128]]
# Failed to complete in trial number 80 in 500 steps
# [[  4   8   4  32]
#  [  2   4  16  64]
#  [  4  16  64   4]
#  [  2   8  16 256]]
# Failed to complete in trial number 81 in 500 steps
# [[  2   4   8  16]
#  [  4  16   4  64]
#  [ 16  32  64 128]
#  [  2  64 128 256]]
# Failed to complete in trial number 82 in 500 steps
# [[ 2  4  8 16]
#  [ 4  2 32  2]
#  [ 8 16 64  4]
#  [ 2  4 16 32]]
# Failed to complete in trial number 83 in 500 steps
# [[  2   4  32   2]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32 128   2]]
# Failed to complete in trial number 84 in 500 steps
# [[  2   8   2  16]
#  [  4   2  16   2]
#  [  8   4  64   4]
#  [  4   2 128 256]]
# Failed to complete in trial number 85 in 500 steps
# [[  4   2   8  16]
#  [  2   4  16  32]
#  [  4   8 128   2]
#  [  2  16   8 128]]
# Failed to complete in trial number 86 in 500 steps
# [[  2   4   8  16]
#  [  4   2  16  32]
#  [  2  16   2  64]
#  [ 16   2  64 128]]
# Failed to complete in trial number 87 in 500 steps
# [[  4   2   4   8]
#  [  2   4   8  32]
#  [  4  16  32 128]
#  [  2  32  64 256]]
# Failed to complete in trial number 88 in 500 steps
# [[  2   8   2   8]
#  [  4   2   8  16]
#  [  2   4  16  32]
#  [  8  16  32 256]]
# Failed to complete in trial number 89 in 500 steps
# [[  2   4  16  32]
#  [  4   2  32  64]
#  [ 16   4   2   4]
#  [  4  64 512   2]]
# Failed to complete in trial number 90 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [  8  16 128  16]
#  [  2   4   8  64]]
# Failed to complete in trial number 91 in 500 steps
# [[  2   4   8  16]
#  [  4   8   4  32]
#  [  8  32  16  64]
#  [  2  16  64 128]]
# Failed to complete in trial number 92 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [ 16   4  64 128]]
# Failed to complete in trial number 93 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32  64 256]]
# Failed to complete in trial number 94 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  8  16  64   2]
#  [  2  32   4 128]]
# Failed to complete in trial number 95 in 500 steps
# [[  2   4   2   4]
#  [  4   2   8  16]
#  [  8  32  16  64]
#  [  2   8  64 128]]
# Failed to complete in trial number 96 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [ 32  16  32 128]
#  [  2   4  64 256]]
# Failed to complete in trial number 97 in 500 steps
# [[  2   4   2  16]
#  [  4   2  16  32]
#  [  8   4   8 128]
#  [  2  32  64   2]]
# Failed to complete in trial number 98 in 500 steps
# [[ 2  4  2  8]
#  [ 4  2  8 32]
#  [ 8 16 32 64]
#  [ 2 32  8  2]]
# Failed to complete in trial number 99 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [ 16  32  64 128]
#  [  2   8 128 256]]
# Failed to complete in trial number 100 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [ 16   4   2 256]]
# Failed to complete in trial number 101 in 500 steps
# [[  4   2   4  16]
#  [  2   8  32  64]
#  [ 16  32  64 128]
#  [  2   4 128 256]]
# Failed to complete in trial number 102 in 500 steps
# [[  2   4   2   4]
#  [  4   2   4  32]
#  [  8  16  32   4]
#  [  2   4  64 256]]
# Failed to complete in trial number 103 in 500 steps
# [[ 4  2  4 32]
#  [ 2  8 32 64]
#  [ 8 16 64  2]
#  [ 2  4 32  8]]
# Failed to complete in trial number 104 in 500 steps
# [[  4   2   4   8]
#  [  2   4   8  32]
#  [  4  16  32 128]
#  [ 16  32 128 256]]
# Failed to complete in trial number 105 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16  32   2]
#  [  2   4 128 256]]
# Failed to complete in trial number 106 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 107 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  32  64 128]
#  [  2 128 256   2]]
# Failed to complete in trial number 108 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 109 in 500 steps
# [[  4   2   4  16]
#  [  2   4  16  32]
#  [  4  16  32  64]
#  [  2  32  64 256]]
# Failed to complete in trial number 110 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 64]
#  [ 8 16 64  4]
#  [ 2  8 16 32]]
# Failed to complete in trial number 111 in 500 steps
# [[  4   8   2   4]
#  [  2  32   4  32]
#  [  4   8  16  64]
#  [  2   4  64 128]]
# Failed to complete in trial number 112 in 500 steps
# [[  2   8  32   2]
#  [  4  32   2   8]
#  [  8  16   8  32]
#  [  2   4  32 128]]
# Failed to complete in trial number 113 in 500 steps
# [[  4   2   4   2]
#  [  2  16   8  16]
#  [  4  32   2  64]
#  [  2  16  64 256]]
# Failed to complete in trial number 114 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  64   4 128]
#  [ 32   2 128 256]]
# Failed to complete in trial number 115 in 500 steps
# [[ 2  4  2  8]
#  [ 4 16  4 32]
#  [16  2 16 64]
#  [ 2  8 64  8]]
# Failed to complete in trial number 116 in 500 steps
# [[  4   2   4   2]
#  [  2   4   8   4]
#  [  4  16   2  16]
#  [  2  32   8 256]]
# Failed to complete in trial number 117 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  8  16  64 128]
#  [ 16  64 128   2]]
# Failed to complete in trial number 118 in 500 steps
# [[  4   2   4  16]
#  [  2   4   8  32]
#  [  4  16  32   2]
#  [  2   8  16 128]]
# Failed to complete in trial number 119 in 500 steps
# [[  2   4  16  32]
#  [  4   8  32   2]
#  [  8  16  64   8]
#  [  2  32 128 256]]
# Failed to complete in trial number 120 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  2  32  64   8]
#  [  8   2  16 256]]
# Failed to complete in trial number 121 in 500 steps
# [[  4   2   4  16]
#  [  8  16  32   2]
#  [  4  32   4   8]
#  [  2  64   2 256]]
# Failed to complete in trial number 122 in 500 steps
# [[  4   2   4  16]
#  [  2   4  16  32]
#  [  4   8   2  16]
#  [  2  16  64 128]]
# Failed to complete in trial number 123 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [ 16  64  32  64]
#  [  4  16  64 128]]
# Failed to complete in trial number 124 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16   2]
#  [  2  16  64 128]
#  [ 16   2 128 256]]
# Failed to complete in trial number 125 in 500 steps
# [[  2   4   2   4]
#  [  4   8   4  32]
#  [  8  32  16  64]
#  [  2  16   8 128]]
# Failed to complete in trial number 126 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  64]
#  [  8  16  32 128]
#  [  4   8 128   4]]
# Failed to complete in trial number 127 in 500 steps
# [[  4   2   4   8]
#  [  8   4   8  32]
#  [ 16  32  16 256]
#  [  4   8  32   8]]
# Failed to complete in trial number 128 in 500 steps
# [[  2   4   8   2]
#  [  4   8   2   4]
#  [  8   2  16  64]
#  [  2   4  32 128]]
# Failed to complete in trial number 129 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  4  32   2 256]]
# Failed to complete in trial number 130 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32   2]
#  [  8  32  64   8]
#  [  2  16 128  16]]
# Failed to complete in trial number 131 in 500 steps
# [[ 2  4  2  4]
#  [ 4 16  8 32]
#  [ 8 32 64  8]
#  [16  2  8 64]]
# Failed to complete in trial number 132 in 500 steps
# [[  2   4   8   2]
#  [  4   8   2  16]
#  [  8   2   8  64]
#  [  2  16  32 128]]
# Failed to complete in trial number 133 in 500 steps
# [[  2   4   8   2]
#  [  4  16   2  64]
#  [  2  32  64 128]
#  [ 16   2   8  64]]
# Failed to complete in trial number 134 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [  2   4 128   4]]
# Failed to complete in trial number 135 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  64]
#  [  8  16  64 128]
#  [ 16   2  16 256]]
# Failed to complete in trial number 136 in 500 steps
# [[ 2  4  2  8]
#  [ 4  2  4 16]
#  [ 2  4  8 32]
#  [ 4  2  4 64]]
# Failed to complete in trial number 137 in 500 steps
# [[  4   2   8  16]
#  [  2   4  16  64]
#  [  8  16  32   4]
#  [ 16   2  64 256]]
# Failed to complete in trial number 138 in 500 steps
# [[  2   4   8  32]
#  [  4   2  16  64]
#  [  2   8  32 128]
#  [  8  16  64 256]]
# Failed to complete in trial number 139 in 500 steps
# [[ 2  4  2 16]
#  [ 4  2 16 32]
#  [ 8 16 32  2]
#  [ 2 32 64  4]]
# Failed to complete in trial number 140 in 500 steps
# [[  4   2   8   2]
#  [  2   8  16  64]
#  [  8  16  32 128]
#  [  2  64 256   4]]
# Failed to complete in trial number 141 in 500 steps
# [[ 4  2  4 16]
#  [16  8  2 64]
#  [ 4 32  8 32]
#  [ 2  8 32  4]]
# Failed to complete in trial number 142 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16   2  64]
#  [  4  32  64 256]]
# Failed to complete in trial number 143 in 500 steps
# [[ 4  2  8 16]
#  [ 2  4 16 32]
#  [ 4 16 64  2]
#  [ 8 64  4 16]]
# Failed to complete in trial number 144 in 500 steps
# [[  2   8   2   8]
#  [  4   2   8  16]
#  [  8  64  16  64]
#  [  2   4 128   4]]
# Failed to complete in trial number 145 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 146 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  8  16  32  64]
#  [  2  32   8 256]]
# Failed to complete in trial number 147 in 500 steps
# [[  2   4   8   2]
#  [  4  16   2  16]
#  [  2   4   8  64]
#  [  4   2  16 128]]
# Failed to complete in trial number 148 in 500 steps
# [[  2   4   8  16]
#  [  4   8   2  64]
#  [  8  16  32   4]
#  [  4  32  64 128]]
# Failed to complete in trial number 149 in 500 steps
# [[  2   4   8  32]
#  [  4   8  32  64]
#  [  2  32  64 128]
#  [  4  64   2   8]]
# Failed to complete in trial number 150 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [  8  16   2 128]
#  [  4   8  16   2]]
# Failed to complete in trial number 151 in 500 steps
# [[  2   4   2  16]
#  [  4   8  16   2]
#  [  8  16  32 128]
#  [  2  64   4   8]]
# Failed to complete in trial number 152 in 500 steps
# [[  4   2   8   2]
#  [  2   4   2  64]
#  [ 16   8  32 256]
#  [  2  32  64   8]]
# Failed to complete in trial number 153 in 500 steps
# [[  2   4   2  16]
#  [  4   2   4  32]
#  [  2   4  16   2]
#  [  8  16  64 128]]
# Failed to complete in trial number 154 in 500 steps
# [[  4   2   8  16]
#  [  2   8   2  32]
#  [  4   2  64 128]
#  [  8  16   4   8]]
# Failed to complete in trial number 155 in 500 steps
# [[  2   4   8   2]
#  [  4  16 128  64]
#  [ 16  64 256   2]
#  [  2   4   8  16]]
# Failed to complete in trial number 156 in 500 steps
# [[  2   4   2   8]
#  [  4   2  16  32]
#  [ 16   4  32 128]
#  [  2   8  16   2]]
# Failed to complete in trial number 157 in 500 steps
# [[  2   4   2   8]
#  [  8   2   8  16]
#  [ 16   4  16  32]
#  [  4   8  32 128]]
# Failed to complete in trial number 158 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 32]
#  [ 8 16 32  2]
#  [ 2  4  2 16]]
# Failed to complete in trial number 159 in 500 steps
# [[ 2  4  8  2]
#  [ 4  8 16 64]
#  [ 8 32 64  2]
#  [ 2  4 16 32]]
# Failed to complete in trial number 160 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [  2   4   8  32]]
# Failed to complete in trial number 161 in 500 steps
# [[  4   2   4   8]
#  [  2   4  16  64]
#  [  4  16  64 128]
#  [  2   4 128   8]]
# Failed to complete in trial number 162 in 500 steps
# [[  2   4   2  32]
#  [  4   8  32  64]
#  [  8  16  64 128]
#  [  2  64   2   8]]
# Failed to complete in trial number 163 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16   2  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 164 in 500 steps
# [[  2   4   2  32]
#  [  4   8  16  64]
#  [  8  16  64 128]
#  [  2   8 128   8]]
# Failed to complete in trial number 165 in 500 steps
# [[  4   2   8  16]
#  [  2   8  32   2]
#  [  8  16   4  64]
#  [  2   4  16 128]]
# Failed to complete in trial number 166 in 500 steps
# [[  2   4   8  16]
#  [  4   2  16  32]
#  [  2   4   2 128]
#  [  8  16  64 256]]
# Failed to complete in trial number 167 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  64]
#  [  8  16  32   4]
#  [  2  32   2 128]]
# Failed to complete in trial number 168 in 500 steps
# [[  2   8   2   8]
#  [  4  16  32  64]
#  [  8  32 128   2]
#  [ 16   4   8 128]]
# Failed to complete in trial number 169 in 500 steps
# [[  4   2   4   8]
#  [  2  16   8  32]
#  [ 16  32   2  64]
#  [  2   8 128   2]]
# Failed to complete in trial number 170 in 500 steps
# [[ 4  8  4  8]
#  [ 2 16  2 16]
#  [ 4  2  4  2]
#  [ 2  4 16 64]]
# Failed to complete in trial number 171 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [ 32   4 256   2]]
# Failed to complete in trial number 172 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8  2 64]
#  [ 8 32 64  4]
#  [32  2  8 64]]
# Failed to complete in trial number 173 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  2  16  32 128]
#  [  4  32 128   8]]
# Failed to complete in trial number 174 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   4]
#  [  8  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 175 in 500 steps
# [[ 2  4 16 32]
#  [ 4  8 32 64]
#  [ 8 32 64  2]
#  [16 64  2 64]]
# Failed to complete in trial number 176 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16  32   2]
#  [  2  64 128   8]]
# Failed to complete in trial number 177 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16  64 128]
#  [  2  32   2   4]]
# Failed to complete in trial number 178 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2  32  64 128]
#  [  4  16 128 256]]
# Failed to complete in trial number 179 in 500 steps
# [[  2   4   8  16]
#  [  8  16  64   2]
#  [  4  64  32 128]
#  [  2   8 256   2]]
# Failed to complete in trial number 180 in 500 steps
# [[ 4  2  4 32]
#  [ 2  8 16 64]
#  [ 8 16  2  4]
#  [ 2  4  8 64]]
# Failed to complete in trial number 181 in 500 steps
# [[  8   2   4   8]
#  [  2   4  16  64]
#  [  4   8  64 128]
#  [  2   4 128 256]]
# Failed to complete in trial number 182 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [  2   4   2   8]]
# Failed to complete in trial number 183 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 32]
#  [ 8 16 32  8]
#  [16 32  2 32]]
# Failed to complete in trial number 184 in 500 steps
# [[  4   2   8   2]
#  [  2   8  16  32]
#  [  8  16   2  64]
#  [  2   8  64 128]]
# Failed to complete in trial number 185 in 500 steps
# [[  4   2   4   8]
#  [  8  32   8  16]
#  [  2   8  16  64]
#  [  8  32   4 128]]
# Failed to complete in trial number 186 in 500 steps
# [[  8   2   4  16]
#  [  2   4  32   2]
#  [  4  32  64 128]
#  [  2  64   2 256]]
# Failed to complete in trial number 187 in 500 steps
# [[  4   2   4   8]
#  [  2   4   8  64]
#  [  8  16  64 128]
#  [  2  32 128   2]]
# Failed to complete in trial number 188 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2  32   4  64]
#  [  8  16  64 128]]
# Failed to complete in trial number 189 in 500 steps
# [[  2   8   2   4]
#  [  4  32   8  16]
#  [  8  16   4 128]
#  [ 16   4  32   2]]
# Failed to complete in trial number 190 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16  2]
#  [ 8 32 64  8]
#  [ 2  8 16 64]]
# Failed to complete in trial number 191 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  64 128   2]]
# Failed to complete in trial number 192 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32   4]
#  [  8  32 128   8]
#  [  2  64   2 256]]
# Failed to complete in trial number 193 in 500 steps
# [[  2   4   2   4]
#  [  8   2   4  16]
#  [  2  16   8   2]
#  [ 16   4  64 128]]
# Failed to complete in trial number 194 in 500 steps
# [[  2   8   4  32]
#  [  8  32  16  64]
#  [  2   8  64 128]
#  [  4   2 128   2]]
# Failed to complete in trial number 195 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  2  16  32  64]
#  [  4  32  64 128]]
# Failed to complete in trial number 196 in 500 steps
# [[  2   4  16  32]
#  [  4  16  32  64]
#  [  2  32  64 128]
#  [  4   8 128 256]]
# Failed to complete in trial number 197 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2  32   2  64]
#  [  4  16  32 128]]
# Failed to complete in trial number 198 in 500 steps
# [[  4   2   4   2]
#  [  2   4  64   8]
#  [  4  16   4  64]
#  [ 16   8 128   2]]
# Failed to complete in trial number 199 in 500 steps
# [[  4   2   8  32]
#  [  8   4  16  64]
#  [  2  16  32 128]
#  [  4  32  64   2]]
# Failed to complete in trial number 200 in 500 steps
# [[  2   8   2  32]
#  [  4  16  32  64]
#  [  8  32 128   2]
#  [  4   2 256   4]]
# Failed to complete in trial number 201 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [  2  32 128   2]]
# Failed to complete in trial number 202 in 500 steps
# [[  4   2   4   2]
#  [  2   4  16   8]
#  [  8  32   8   2]
#  [  4 128  32   4]]
# Failed to complete in trial number 203 in 500 steps
# [[  4   2   4  16]
#  [  2   4  16  64]
#  [  4   8  32 256]
#  [  8   4   8  64]]
# Failed to complete in trial number 204 in 500 steps
# [[  4   2   4   8]
#  [  8  16   8  32]
#  [ 16   8 128  16]
#  [  2   4   8  32]]
# Failed to complete in trial number 205 in 500 steps
# [[  2   8   2   4]
#  [  4   2   4   8]
#  [  8  16   8  16]
#  [  2   8  32 128]]
# Failed to complete in trial number 206 in 500 steps
# [[  4   8  16  32]
#  [  2  16  32  64]
#  [  4  32  64 128]
#  [ 16   2   4  32]]
# Failed to complete in trial number 207 in 500 steps
# [[  4   2   4  32]
#  [  2   8  32  64]
#  [  4  16  64 256]
#  [  8  32   4  32]]
# Failed to complete in trial number 208 in 500 steps
# [[ 2  4  2  4]
#  [ 4  8  4  8]
#  [ 8  4  8 16]
#  [ 2  8 16 64]]
# Failed to complete in trial number 209 in 500 steps
# [[  4   2   4  32]
#  [  2   8  16  64]
#  [  4  16 128 256]
#  [  2   8  16  32]]
# Failed to complete in trial number 210 in 500 steps
# [[ 2  4  8 32]
#  [ 4  8 16 64]
#  [ 8 16 64  2]
#  [ 2  4 16 32]]
# Failed to complete in trial number 211 in 500 steps
# [[ 2  4  2 32]
#  [ 4  2  4 16]
#  [16  8 16 64]
#  [ 2 16  2  8]]
# Failed to complete in trial number 212 in 500 steps
# [[  4   2   4  32]
#  [  2   4  16  64]
#  [  4   8  32   4]
#  [  8  32   8 256]]
# Failed to complete in trial number 213 in 500 steps
# [[  4   2   4   8]
#  [  2   4  16  32]
#  [  4  16   4  64]
#  [ 16  32   8 128]]
# Failed to complete in trial number 214 in 500 steps
# [[  4   2   8  32]
#  [  2   4  16  64]
#  [  4   8  32 128]
#  [  2  32  64 256]]
# Failed to complete in trial number 215 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 32 64]
#  [32 16 64  2]
#  [ 4 64  2 16]]
# Failed to complete in trial number 216 in 500 steps
# [[ 4  2  8 16]
#  [ 2  4 16 64]
#  [ 4  8 32  2]
#  [ 8 64  4 16]]
# Failed to complete in trial number 217 in 500 steps
# [[ 2  4  2  8]
#  [ 4 16  4 16]
#  [ 8  2  8 64]
#  [ 2 16 32  4]]
# Failed to complete in trial number 218 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [  8  16  32   2]
#  [  2  64 256   8]]
# Failed to complete in trial number 219 in 500 steps
# [[  2   4   2   8]
#  [  4   8  64   2]
#  [ 16  32 128   4]
#  [  2  64   2 256]]
# Failed to complete in trial number 220 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  64 128   4]
#  [  4  16   4  16]]
# Failed to complete in trial number 221 in 500 steps
# [[  4   2  16  32]
#  [ 16   8  32  64]
#  [  4  32  64 128]
#  [  2   8 128 256]]
# Failed to complete in trial number 222 in 500 steps
# [[  2   4   2  16]
#  [  4   8  16  64]
#  [  2  64  32 128]
#  [  4   8   4   8]]
# Failed to complete in trial number 223 in 500 steps
# [[  2   4   8  16]
#  [ 16   8  32  64]
#  [  4  32   2  32]
#  [  2   8  64 128]]
# Failed to complete in trial number 224 in 500 steps
# [[  2   4  16  32]
#  [  4   8  32   2]
#  [  8  16  64   4]
#  [  2  64 128 256]]
# Failed to complete in trial number 225 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [ 16  32  64   4]
#  [  2  16  32 128]]
# Failed to complete in trial number 226 in 500 steps
# [[  4   2   8  16]
#  [  2   4  16  64]
#  [  4   8  64   2]
#  [  2  32   4 256]]
# Failed to complete in trial number 227 in 500 steps
# [[ 4  2  8  2]
#  [ 2  8  2  8]
#  [16  2  4 32]
#  [ 4 32  2 64]]
# Failed to complete in trial number 228 in 500 steps
# [[  4   2  16  32]
#  [  2   8  32   2]
#  [  8  32  64  16]
#  [  2  16   2 256]]
# Failed to complete in trial number 229 in 500 steps
# [[  2   8  16  32]
#  [  4  16   2  64]
#  [  8  32  64 256]
#  [ 32   2  16 128]]
# Failed to complete in trial number 230 in 500 steps
# [[ 2  4  8  2]
#  [ 4  8 16 64]
#  [ 8 16 32  2]
#  [ 2 32  4 64]]
# Failed to complete in trial number 231 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2   4  32 128]
#  [  4   2  64   4]]
# Failed to complete in trial number 232 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16   4]
#  [  8  16  64   8]
#  [ 16   2   4 128]]
# Failed to complete in trial number 233 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16   4]
#  [  8  16  32  64]
#  [  2  64   2 256]]
# Failed to complete in trial number 234 in 500 steps
# [[ 4  2  4  2]
#  [ 2  4  2 16]
#  [ 8  2 16 64]
#  [ 2 16 32  8]]
# Failed to complete in trial number 235 in 500 steps
# [[  4   2   4   2]
#  [  2   4  16  32]
#  [  4  16  32  64]
#  [ 16  32   4 128]]
# Failed to complete in trial number 236 in 500 steps
# [[  4   2   8  16]
#  [  2   8  16  32]
#  [ 32  16  32 128]
#  [  2   4  64   2]]
# Failed to complete in trial number 237 in 500 steps
# [[  2   4   2  32]
#  [  4   8  16   2]
#  [  8  16  64 128]
#  [  4   2 128 256]]
# Failed to complete in trial number 238 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  2  16   2 128]
#  [ 16  64   4   8]]
# Failed to complete in trial number 239 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  8  16  64   2]
#  [  4  32   2 128]]
# Failed to complete in trial number 240 in 500 steps
# [[ 4  2  4  2]
#  [ 2  4  8  4]
#  [ 4  2 32  2]
#  [ 2 16  4  8]]
# Failed to complete in trial number 241 in 500 steps
# [[  2   4   2   8]
#  [  8  64   8  16]
#  [  2   4   2  64]
#  [  4   2  32 128]]
# Failed to complete in trial number 242 in 500 steps
# [[  2   4  16   2]
#  [  4  16  32   8]
#  [  8  32   8  64]
#  [ 16   4   2 128]]
# Failed to complete in trial number 243 in 500 steps
# [[  2   4  16   2]
#  [  4   8  32  64]
#  [  8  16  64   4]
#  [  4   2  16 128]]
# Failed to complete in trial number 244 in 500 steps
# [[ 2  4  8 16]
#  [16  8 16 32]
#  [ 4 16 32  2]
#  [ 2 64  4 32]]
# Failed to complete in trial number 245 in 500 steps
# [[ 2  4  2  8]
#  [ 4  2  8  2]
#  [ 8  4 16 32]
#  [ 2 16 32 64]]
# Failed to complete in trial number 246 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2   8  64 128]]
# Failed to complete in trial number 247 in 500 steps
# [[ 4  2  4 16]
#  [ 2  4 16 32]
#  [32  8 32  4]
#  [ 2 64  2 64]]
# Failed to complete in trial number 248 in 500 steps
# [[  2   4  16  32]
#  [  4   8  32  64]
#  [  8  16  64 256]
#  [  2   4  16  32]]
# Failed to complete in trial number 249 in 500 steps
# [[  2   4   2   4]
#  [  4  16   4  16]
#  [  8   4  16  64]
#  [ 16   8  32 256]]
# Failed to complete in trial number 250 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  32  64 128]
#  [ 16   2   8  16]]
# Failed to complete in trial number 251 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   4]
#  [ 16  32   4  32]
#  [  2   4  64 128]]
# Failed to complete in trial number 252 in 500 steps
# [[ 4  2  8  2]
#  [16  8  2  8]
#  [ 4  2  4 16]
#  [ 2  8 16  2]]
# Failed to complete in trial number 253 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  8   2  64 128]
#  [  2  64 128 512]]
# Failed to complete in trial number 254 in 500 steps
# [[  2   8   2  16]
#  [  4   2   8  32]
#  [  2   8   4 128]
#  [  4   2  32  64]]
# Failed to complete in trial number 255 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32   2]
#  [  2   8  64 128]]
# Failed to complete in trial number 256 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 64]
#  [32 16 64  4]
#  [ 2 64 16 64]]
# Failed to complete in trial number 257 in 500 steps
# [[  2   4  16   2]
#  [  4   2  64   4]
#  [  2  16  32 128]
#  [  8  64 128 256]]
# Failed to complete in trial number 258 in 500 steps
# [[ 2  4  8 32]
#  [ 4  8 32 64]
#  [ 8 32 64  2]
#  [ 4 64 16 32]]
# Failed to complete in trial number 259 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2  32  64 128]
#  [  4   8   2   8]]
# Failed to complete in trial number 260 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [  8  16  64   4]
#  [  2  32   4 256]]
# Failed to complete in trial number 261 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16   4 128]
#  [  2  32  64   2]]
# Failed to complete in trial number 262 in 500 steps
# [[ 2  4  2  8]
#  [ 4  8 16 64]
#  [ 8 16 64  2]
#  [16 32  4 16]]
# Failed to complete in trial number 263 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [ 16   2 128 256]]
# Failed to complete in trial number 264 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  32]
#  [  8  16   4 256]
#  [  2  32 128   2]]
# Failed to complete in trial number 265 in 500 steps
# [[ 2  4  2 16]
#  [ 4 16  8 32]
#  [ 2  4 32 64]
#  [ 8 16 64  2]]
# Failed to complete in trial number 266 in 500 steps
# [[  2   4   2  32]
#  [  4   8  16  64]
#  [  8   2   4  32]
#  [  2   8  16 128]]
# Failed to complete in trial number 267 in 500 steps
# [[  4   2   8  16]
#  [  8   4  16   2]
#  [ 16   8  32  64]
#  [  2  64   4 256]]
# Failed to complete in trial number 268 in 500 steps
# [[  2   8  16  32]
#  [  4  16  32  64]
#  [  8  32  64 128]
#  [ 32   4   8 256]]
# Failed to complete in trial number 269 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [ 16  64   4 128]
#  [  4   8  64 256]]
# Failed to complete in trial number 270 in 500 steps
# [[ 2  4  2  8]
#  [ 4 16  8 16]
#  [ 8  2 64  2]
#  [ 2  4  8 32]]
# Failed to complete in trial number 271 in 500 steps
# [[  2   4   8  16]
#  [  4  16  32  64]
#  [  2  32  64 128]
#  [  4   8  16 256]]
# Failed to complete in trial number 272 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  32]
#  [ 16  32 128   2]
#  [  2   4   8 256]]
# Failed to complete in trial number 273 in 500 steps
# [[  2   8   2   4]
#  [  8   4  32   8]
#  [ 16   2   4  64]
#  [  2  32  64 256]]
# Failed to complete in trial number 274 in 500 steps
# [[  2   4  16   2]
#  [  4   8   2   8]
#  [  8   2  16  64]
#  [  2  64 128   2]]
# Failed to complete in trial number 275 in 500 steps
# [[  2   4   2   8]
#  [  4   8   4  16]
#  [ 16   4  16  32]
#  [  2   8  64 256]]
# Failed to complete in trial number 276 in 500 steps
# [[  2   4   2   8]
#  [  4   2  16  32]
#  [  8  16  32 128]
#  [  2   8 128   8]]
# Failed to complete in trial number 277 in 500 steps
# [[  4   8   2   8]
#  [  2  16  32  64]
#  [  8  32  64 128]
#  [ 16   2   8  16]]
# Failed to complete in trial number 278 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8   2  64 128]
#  [ 16  64  16  32]]
# Failed to complete in trial number 279 in 500 steps
# [[  4   2   4  16]
#  [  2   4  16  32]
#  [  8  16  32  64]
#  [ 16  32   2 256]]
# Failed to complete in trial number 280 in 500 steps
# [[  2   8  16   4]
#  [  4  16  32   2]
#  [  8  32   4  64]
#  [  2   8   2 128]]
# Failed to complete in trial number 281 in 500 steps
# [[  2   8   2   4]
#  [  4   2   4  16]
#  [  8  64   8  32]
#  [ 16   2  16 128]]
# Failed to complete in trial number 282 in 500 steps
# [[  2   4   2  16]
#  [  4   2   8  64]
#  [ 16   8  16 128]
#  [  2  32   2   8]]
# Failed to complete in trial number 283 in 500 steps
# [[  2   8   2   4]
#  [  4  32  16   2]
#  [ 16   8 128  64]
#  [  2   4  16 256]]
# Failed to complete in trial number 284 in 500 steps
# [[  2   4   8  32]
#  [  4   8  32  64]
#  [  2  32  64 256]
#  [  8   4   8  64]]
# Failed to complete in trial number 285 in 500 steps
# [[  2   4   2   4]
#  [  4   8  16  64]
#  [  8  16  32   4]
#  [ 16  32 128 256]]
# Failed to complete in trial number 286 in 500 steps
# [[  2   4   8   2]
#  [  4   2  32   4]
#  [  2  16 128   8]
#  [  4  32 256   2]]
# Failed to complete in trial number 287 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 32]
#  [ 8 16 64  2]
#  [ 2 64  2 32]]
# Failed to complete in trial number 288 in 500 steps
# [[  4   2   8  16]
#  [  2   8  16   2]
#  [  4  16  64   4]
#  [  8   2  32 512]]
# Failed to complete in trial number 289 in 500 steps
# [[  4   2   4  16]
#  [  2   8  16  32]
#  [  4  16  32 128]
#  [  2  32   4 256]]
# Failed to complete in trial number 290 in 500 steps
# [[  2   4   2   4]
#  [  4  16   4   8]
#  [  8   2   8  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 291 in 500 steps
# [[ 4  2  4  8]
#  [ 2  8 16 32]
#  [ 4 16 64  2]
#  [ 2  4  8 64]]
# Failed to complete in trial number 292 in 500 steps
# [[  4   2   4   8]
#  [  2   4   8  32]
#  [  8  16  32  64]
#  [ 16  32  64 512]]
# Failed to complete in trial number 293 in 500 steps
# [[  8   2   8  16]
#  [  2  16   2   4]
#  [  4   8  16  32]
#  [  2  16  64 128]]
# Failed to complete in trial number 294 in 500 steps
# [[ 2  4  2  4]
#  [ 4 16  4 16]
#  [ 8  4  8 64]
#  [32  8  2  4]]
# Failed to complete in trial number 295 in 500 steps
# [[ 2  8  2  8]
#  [ 8  2  8 32]
#  [ 2  4 16  2]
#  [ 4 16  4 64]]
# Failed to complete in trial number 296 in 500 steps
# [[ 2  4  8  4]
#  [ 4  8 32  8]
#  [ 8 16 64  4]
#  [ 2 32  2 32]]
# Failed to complete in trial number 297 in 500 steps
# [[  4   8   2   8]
#  [  2   4  16  64]
#  [  4  32  64 128]
#  [  8   2   4  64]]
# Failed to complete in trial number 298 in 500 steps
# [[  4   8  16  32]
#  [  2   4  32  64]
#  [  8  16  64 128]
#  [  4  64 256   2]]
# Failed to complete in trial number 299 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16   8]
#  [  8  16   2  64]
#  [  2   8  16 128]]
# Failed to complete in trial number 300 in 500 steps
# [[  2   4  16   2]
#  [  4  16  64   4]
#  [  8  32   2  64]
#  [  2   8  32 128]]
# Failed to complete in trial number 301 in 500 steps
# [[ 2  8  2  4]
#  [ 4 16  4  8]
#  [32  8 16 64]
#  [ 2  4 64  2]]
# Failed to complete in trial number 302 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32  16]
#  [  8  16  64 128]
#  [  2   4   2 256]]
# Failed to complete in trial number 303 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2  16  32 128]
#  [  8   2   8  16]]
# Failed to complete in trial number 304 in 500 steps
# [[  2   4   8  32]
#  [  4   8  32  64]
#  [  8  16  64 256]
#  [  2  64 128   8]]
# Failed to complete in trial number 305 in 500 steps
# [[ 4  2  4  8]
#  [ 2  4  8 32]
#  [16  8 16 64]
#  [ 2 32  2  4]]
# Failed to complete in trial number 306 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  8  16  32  64]
#  [  4  32  64 128]]
# Failed to complete in trial number 307 in 500 steps
# [[  4   2   4  16]
#  [  2   8  16  32]
#  [  4  16   4 128]
#  [  2  32 128   2]]
# Failed to complete in trial number 308 in 500 steps
# [[  4   8   4   8]
#  [  2  64  16  64]
#  [  4  16  32   2]
#  [  8   2 128 256]]
# Failed to complete in trial number 309 in 500 steps
# [[  2   4   8  32]
#  [  4   8   4  64]
#  [  8  16  64   2]
#  [  2   8 128 256]]
# Failed to complete in trial number 310 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32  64]
#  [  8  32  64 128]
#  [  2   8 128   8]]
# Failed to complete in trial number 311 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8   2   8 128]
#  [  2   4 128   4]]
# Failed to complete in trial number 312 in 500 steps
# [[ 2  8  2 32]
#  [ 4 16  8 64]
#  [16 32  2  8]
#  [ 2  4  8 64]]
# Failed to complete in trial number 313 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 64]
#  [ 8 16 64  4]
#  [ 2 32  4 16]]
# Failed to complete in trial number 314 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32  16]
#  [ 16   2  16 128]
#  [  2  32  64   4]]
# Failed to complete in trial number 315 in 500 steps
# [[  2   4   2  32]
#  [  8  32  16   2]
#  [  2  16 128   4]
#  [  8   2   4 128]]
# Failed to complete in trial number 316 in 500 steps
# [[ 2  8  4 16]
#  [ 4 32 16 64]
#  [ 2 16  2  4]
#  [ 8  4 32 64]]
# Failed to complete in trial number 317 in 500 steps
# [[  2   4   2  16]
#  [  4   8   4  64]
#  [  8  32  16 128]
#  [  2   4 128   2]]
# Failed to complete in trial number 318 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  64]
#  [  8  16  64 128]
#  [ 16  32   4   8]]
# Failed to complete in trial number 319 in 500 steps
# [[  2   4   2  16]
#  [  4  32  16  32]
#  [  2  16   2 128]
#  [  8   2  64 256]]
# Failed to complete in trial number 320 in 500 steps
# [[  4   2   4  32]
#  [  2   8  16  64]
#  [  8  16  32   2]
#  [  4  32  64 128]]
# Failed to complete in trial number 321 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [  2  16 128   2]
#  [  4   8  64 128]]
# Failed to complete in trial number 322 in 500 steps
# [[ 2  4  2  4]
#  [ 4  8 16 32]
#  [ 8  2 32 64]
#  [ 2  8  2 16]]
# Failed to complete in trial number 323 in 500 steps
# [[ 8  2  4 32]
#  [ 2  4 16 64]
#  [ 4 16 32  2]
#  [ 2  4 64 16]]
# Failed to complete in trial number 324 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16 256 128]
#  [ 16   2   4  16]]
# Failed to complete in trial number 325 in 500 steps
# [[  2   8   4   8]
#  [  4  16   2  32]
#  [  2   4  32  64]
#  [  4   2   4 256]]
# Failed to complete in trial number 326 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  32  64   2]
#  [  2   4   8 128]]
# Failed to complete in trial number 327 in 500 steps
# [[  2   4  16  32]
#  [  4   8  32 128]
#  [  8  16  64 256]
#  [  2  32   4  32]]
# Failed to complete in trial number 328 in 500 steps
# [[  4   2   8  32]
#  [  2   8  32  64]
#  [  8  16  64 256]
#  [  2  32   4  32]]
# Failed to complete in trial number 329 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8   2  32  64]
#  [ 16  32 128   4]]
# Failed to complete in trial number 330 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  32  64 128]
#  [  4  16   8 256]]
# Failed to complete in trial number 331 in 500 steps
# [[ 4  2  4  2]
#  [ 2 16 32  8]
#  [16 32 64 32]
#  [ 2  4  8 64]]
# Failed to complete in trial number 332 in 500 steps
# [[  4   2   4   8]
#  [  8   4  16  32]
#  [  2  16  64   2]
#  [ 16  64 128  32]]
# Failed to complete in trial number 333 in 500 steps
# [[  2   4   2   4]
#  [  4   2   4  16]
#  [ 16   8  16  32]
#  [  2   4  32 128]]
# Failed to complete in trial number 334 in 500 steps
# [[ 2  4  2 16]
#  [ 4 32  4 32]
#  [ 8  2 16 64]
#  [16  4 64  2]]
# Failed to complete in trial number 335 in 500 steps
# [[ 2  4  8  2]
#  [ 4  8 32 64]
#  [ 8 32 64  4]
#  [ 2 64  8 32]]
# Failed to complete in trial number 336 in 500 steps
# [[  2   4  16   4]
#  [  4  16   4  32]
#  [  8   2  32  64]
#  [  2   4   8 128]]
# Failed to complete in trial number 337 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 64]
#  [ 8 16 32  2]
#  [16  2  8 64]]
# Failed to complete in trial number 338 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  2  16  64 128]
#  [  4  32 128 512]]
# Failed to complete in trial number 339 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16  32 128]
#  [  2  32 128 512]]
# Failed to complete in trial number 340 in 500 steps
# [[  2   4   8  16]
#  [  4   2  16  32]
#  [  2   8  32  64]
#  [ 16  32   8 256]]
# Failed to complete in trial number 341 in 500 steps
# [[  2   4   2   8]
#  [  4   2   8  16]
#  [  2   8  16 128]
#  [  8  32  64 256]]
# Failed to complete in trial number 342 in 500 steps
# [[ 2  4 16  2]
#  [ 4  8  2 16]
#  [ 2 16 32  2]
#  [16  8 16 64]]
# Failed to complete in trial number 343 in 500 steps
# [[  2   4   8  32]
#  [ 16   8  32   4]
#  [  8  32  64   8]
#  [  2   4   8 256]]
# Failed to complete in trial number 344 in 500 steps
# [[  4   2   4   2]
#  [  2   4   8  16]
#  [ 16  32   4 128]
#  [  4   8  16 256]]
# Failed to complete in trial number 345 in 500 steps
# [[ 2  4  2  4]
#  [ 4  2  4 16]
#  [ 8  4 16 32]
#  [ 4 16 32 64]]
# Failed to complete in trial number 346 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32  64 256]]
# Failed to complete in trial number 347 in 500 steps
# [[ 2  4 16 32]
#  [ 4  8 32  2]
#  [ 2 32 64 16]
#  [ 8 64  2 64]]
# Failed to complete in trial number 348 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [ 16  32  64   4]
#  [  2   4 128   2]]
# Failed to complete in trial number 349 in 500 steps
# [[  8   4   2  16]
#  [ 16   2   4  32]
#  [  4   8  16  64]
#  [  2  32   4 128]]
# Failed to complete in trial number 350 in 500 steps
# [[  4   8   4  16]
#  [  2   4  16  64]
#  [  8  64   2 128]
#  [  2   4 128   4]]
# Failed to complete in trial number 351 in 500 steps
# [[ 2  8  2  8]
#  [ 4  2  4 16]
#  [ 8 32  2  8]
#  [ 2 16  8 32]]
# Failed to complete in trial number 352 in 500 steps
# [[  4   8   2  16]
#  [  2  16  32  64]
#  [  8  32   2 128]
#  [  2   4  32 256]]
# Failed to complete in trial number 353 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [  2  32  64   4]]
# Failed to complete in trial number 354 in 500 steps
# [[ 2  4  2 16]
#  [ 4  2 16 32]
#  [ 2 16  4 64]
#  [ 4  8 16  2]]
# Failed to complete in trial number 355 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32   2 256]]
# Failed to complete in trial number 356 in 500 steps
# [[  8   2   4  32]
#  [  2   4  32 128]
#  [  4  32  64 256]
#  [  2   4  16 128]]
# Failed to complete in trial number 357 in 500 steps
# [[ 2  4  8 16]
#  [ 4 16 32  2]
#  [ 8 32  2 32]
#  [ 2 16 32 64]]
# Failed to complete in trial number 358 in 500 steps
# [[  2   4   8  16]
#  [  4  16  32  64]
#  [  8  32  64 128]
#  [  2   4   8 256]]
# Failed to complete in trial number 359 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32  64]
#  [  2  32  64 128]
#  [  4  64  16 256]]
# Failed to complete in trial number 360 in 500 steps
# [[ 4  2  8 16]
#  [ 2  4 16  2]
#  [16  8 32 64]
#  [ 4 32  8 32]]
# Failed to complete in trial number 361 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 32]
#  [ 8 16 32  2]
#  [16 32  4  8]]
# Failed to complete in trial number 362 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  8  16   4  32]
#  [  2   8  32 128]]
# Failed to complete in trial number 363 in 500 steps
# [[  4   2   8   4]
#  [  2   4   2  16]
#  [ 16   8  16  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 364 in 500 steps
# [[ 4  2  4 16]
#  [ 8  4  8 32]
#  [ 4  2 32 64]
#  [ 8 32 64  8]]
# Failed to complete in trial number 365 in 500 steps
# [[ 2  4  8  2]
#  [ 4  8 16  4]
#  [16  2 32 64]
#  [ 4 32 64  4]]
# Failed to complete in trial number 366 in 500 steps
# ...
# [[  2   4   8   4]
#  [  4   8  32   2]
#  [  8  16   2  64]
#  [  2   4   8 128]]
# Failed to complete in trial number 638 in 500 steps
# [[  2   4   2  16]
#  [  4   2  64   2]
#  [  8   4   8  64]
#  [  4  16   2 512]]
# Failed to complete in trial number 639 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2  16  32  64]
#  [  8   4  64 128]]
# Failed to complete in trial number 640 in 500 steps
# [[  2   8   2  16]
#  [ 16   4   8  32]
#  [  4   8  32   2]
#  [  2  16   2 128]]
# Failed to complete in trial number 641 in 500 steps
# [[  4   2   8   4]
#  [  2   8  16  32]
#  [  4  16  64 128]
#  [ 16   2   8  16]]
# Failed to complete in trial number 642 in 500 steps
# [[  2   4  16   4]
#  [  4  16  32   8]
#  [ 16  32  64  16]
#  [ 32   2   8 512]]
# Failed to complete in trial number 643 in 500 steps
# [[  2   4  32   2]
#  [  4   8  16   4]
#  [  8  16  32  16]
#  [ 16  32 128   2]]
# Failed to complete in trial number 644 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32   2]
#  [  2   8 128   4]
#  [  8  16  32  64]]
# Failed to complete in trial number 645 in 500 steps
# [[  2   4   8   4]
#  [  4   2  16  32]
#  [  2  16  32   4]
#  [ 16  32  64 512]]
# Failed to complete in trial number 646 in 500 steps
# [[ 2  8  2  4]
#  [ 8  2 16 32]
#  [ 2  4 32 64]
#  [ 8 16 64  2]]
# Failed to complete in trial number 647 in 500 steps
# [[  4   8   4   2]
#  [  2  16   2  16]
#  [  4   8  32  64]
#  [ 16  32 128   4]]
# Failed to complete in trial number 648 in 500 steps
# [[ 2  4  8  2]
#  [ 4  8 32  4]
#  [ 8 16  2 32]
#  [16 32 64  2]]
# Failed to complete in trial number 649 in 500 steps
# [[  2   4   2   4]
#  [  8   2   4   8]
#  [  2   8  32 128]
#  [ 16  64 128 256]]
# Failed to complete in trial number 650 in 500 steps
# [[ 2  4 16  2]
#  [ 4  2  8 32]
#  [ 2  8  2 64]
#  [ 8 16 64  8]]
# Failed to complete in trial number 651 in 500 steps
# [[  4   2  16   2]
#  [  2   4   8  16]
#  [  4   8  16  32]
#  [  8  32  64 128]]
# Failed to complete in trial number 652 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  8  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 653 in 500 steps
# [[  2   4  16   2]
#  [  4  16  32   4]
#  [  8  32   2   8]
#  [ 32   4 128 256]]
# Failed to complete in trial number 654 in 500 steps
# [[  4   2   8  16]
#  [  2   4  16  64]
#  [  8  16  32   2]
#  [ 16  32 128  16]]
# Failed to complete in trial number 655 in 500 steps
# [[  2   4   8   4]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [ 16  32 128   2]]
# Failed to complete in trial number 656 in 500 steps
# [[  2   4   8   2]
#  [  4  16  32  64]
#  [  8  32  64 128]
#  [ 16   2 128 256]]
# Failed to complete in trial number 657 in 500 steps
# [[  2   4   2  16]
#  [  4   8  16  64]
#  [ 16  64 128   2]
#  [  4   2   4  64]]
# Failed to complete in trial number 658 in 500 steps
# [[ 4  2  4  8]
#  [ 2  4 16 32]
#  [ 4  8 32  2]
#  [ 8  4 16 64]]
# Failed to complete in trial number 659 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16   8]
#  [  8  16   4  32]
#  [ 16   2 128   8]]
# Failed to complete in trial number 660 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32   8]
#  [  8  16   2  64]
#  [ 16  32  64 128]]
# Failed to complete in trial number 661 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32  64]
#  [  8  32  64   4]
#  [  2   8  16 128]]
# Failed to complete in trial number 662 in 500 steps
# [[  2   4  16   2]
#  [  4   8  32  64]
#  [ 16  32  64   2]
#  [  2   4 128 256]]
# Failed to complete in trial number 663 in 500 steps
# [[ 2  4  2  4]
#  [ 4  8 16 64]
#  [ 8 32 64  2]
#  [ 2 64 16 64]]
# Failed to complete in trial number 664 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32   2]
#  [ 16  32  64  32]
#  [  2 128   2  64]]
# Failed to complete in trial number 665 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32  64 128]]
# Failed to complete in trial number 666 in 500 steps
# [[  2   4   2   8]
#  [  4  16  32   4]
#  [  2   8 128   2]
#  [ 16  32   4 128]]
# Failed to complete in trial number 667 in 500 steps
# [[  8   2   4   8]
#  [  4  16   8   2]
#  [  8   2  16  32]
#  [  2  16   4 128]]
# Failed to complete in trial number 668 in 500 steps
# [[  2   4   8   2]
#  [  4   8  64  16]
#  [  8  16   4  64]
#  [  2   4   2 128]]
# Failed to complete in trial number 669 in 500 steps
# [[  4   2   4   8]
#  [  8   4  16   2]
#  [  2  16 128  32]
#  [  8  64   4 256]]
# Failed to complete in trial number 670 in 500 steps
# [[  2   4   8   4]
#  [  4  16  32   8]
#  [  2   8  16  64]
#  [ 16  64   4 128]]
# Failed to complete in trial number 671 in 500 steps
# [[  2   4   8   4]
#  [  4  16   2  32]
#  [ 16  32  16 128]
#  [ 32   2 128   4]]
# Failed to complete in trial number 672 in 500 steps
# [[ 2  4  2  8]
#  [ 4  8 16  2]
#  [ 8 16 32  8]
#  [16 32 64 32]]
# Failed to complete in trial number 673 in 500 steps
# [[  2   4   8  16]
#  [  4   8   4  32]
#  [  8  16  64   4]
#  [ 32   4 128  16]]
# Failed to complete in trial number 674 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32  16]
#  [  8  16  64 128]
#  [ 16  32 128   4]]
# Failed to complete in trial number 675 in 500 steps
# [[  2   4  16   4]
#  [  4   8  32  16]
#  [  8  16 128 256]
#  [ 16  64   2   8]]
# Failed to complete in trial number 676 in 500 steps
# [[ 2  4  8  2]
#  [ 4  8 16 32]
#  [ 8 16 64 16]
#  [16 32  2 64]]
# Failed to complete in trial number 677 in 500 steps
# [[ 4  2  4  2]
#  [ 8  4 64  4]
#  [ 4  8  2  8]
#  [16 64  4  2]]
# Failed to complete in trial number 678 in 500 steps
# [[  4   2   8   4]
#  [  2   8   2  32]
#  [  4  32  16   2]
#  [ 16   2 128   4]]
# Failed to complete in trial number 679 in 500 steps
# [[ 2  4  2  8]
#  [ 8 16  8  2]
#  [ 2  8 32 64]
#  [ 8 32  4 16]]
# Failed to complete in trial number 680 in 500 steps
# [[  2   4   8   4]
#  [  4   8   2  32]
#  [  2  16  64   2]
#  [ 16  32   4 256]]
# Failed to complete in trial number 681 in 500 steps
# [[  2   4   2  16]
#  [  4   8  16   4]
#  [  8   2  32  64]
#  [  4  16  64 128]]
# Failed to complete in trial number 682 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [ 16  32   2 128]
#  [  4  64   4   8]]
# Failed to complete in trial number 683 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16 128   4]
#  [ 16   2  32 128]]
# Failed to complete in trial number 684 in 500 steps
# [[  2   4   2   4]
#  [  4   8  16  64]
#  [  8  16  32   2]
#  [  2  64   8 128]]
# Failed to complete in trial number 685 in 500 steps
# [[  4   2   4   2]
#  [  2   8  16  64]
#  [  4  16  32 128]
#  [  8  32   4  32]]
# Failed to complete in trial number 686 in 500 steps
# [[  4   2   8  16]
#  [  2   8  16  32]
#  [  8 256  32   2]
#  [ 64   8  64   8]]
# Failed to complete in trial number 687 in 500 steps
# [[ 2  4  8  2]
#  [ 4  8  2  4]
#  [ 8 32  4 16]
#  [ 2  4 16 32]]
# Failed to complete in trial number 688 in 500 steps
# [[  2   4  16   2]
#  [  4   2   8  16]
#  [  2  16  32  64]
#  [  8   4  64 128]]
# Failed to complete in trial number 689 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  64]
#  [  8  16  64 512]
#  [ 16   2   4  16]]
# Failed to complete in trial number 690 in 500 steps
# [[  4   2   4   8]
#  [  2   8   2  16]
#  [  8  32   4  64]
#  [ 32   4 128   2]]
# Failed to complete in trial number 691 in 500 steps
# [[  4   2   8  16]
#  [  2   4  16  32]
#  [  4  16   8 128]
#  [  2   8  64   4]]
# Failed to complete in trial number 692 in 500 steps
# [[  2   8   2  16]
#  [  4   2  16  32]
#  [  8   4  32 128]
#  [ 16   2   4   2]]
# Failed to complete in trial number 693 in 500 steps
# [[  2   4   8  32]
#  [  4  16  32  64]
#  [  2  32  64   4]
#  [  4   2   4 128]]
# Failed to complete in trial number 694 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 64]
#  [ 8 16 64  2]
#  [ 4 32  2 32]]
# Failed to complete in trial number 695 in 500 steps
# [[  2   4   2  16]
#  [  4   2   4  32]
#  [  8   4   8 128]
#  [ 16   8  64 256]]
# Failed to complete in trial number 696 in 500 steps
# [[  2   8   2   4]
#  [  4  64   4  16]
#  [ 16   2  16  32]
#  [  2   4   8 256]]
# Failed to complete in trial number 697 in 500 steps
# [[  2   4   2   4]
#  [  4  16  32  16]
#  [  8   2  64   4]
#  [  2   4 256  64]]
# Failed to complete in trial number 698 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   4]
#  [  8  16  32 128]
#  [ 16  64 256   4]]
# Failed to complete in trial number 699 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  2  16  64 128]
#  [  8  32   2 256]]
# Failed to complete in trial number 700 in 500 steps
# [[  2   4  16   2]
#  [  4  16   2  16]
#  [ 16  64 128   2]
#  [  2  32  64  16]]
# Failed to complete in trial number 701 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32  16]
#  [  8  32   2 128]
#  [  2  64   4 256]]
# Failed to complete in trial number 702 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  4  32   8 128]]
# Failed to complete in trial number 703 in 500 steps
# [[  2   4  16   2]
#  [  4  16  32   4]
#  [ 16  64   2  32]
#  [  2   4 128   4]]
# Failed to complete in trial number 704 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [  2  32   4 256]]
# Failed to complete in trial number 705 in 500 steps
# [[  4   2   4  16]
#  [  2   4   8  32]
#  [  4   8  16  64]
#  [ 16  32  64 256]]
# Failed to complete in trial number 706 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32 256]
#  [  4  32  64   8]]
# Failed to complete in trial number 707 in 500 steps
# [[  2   4   2  16]
#  [  4   2  16   4]
#  [  2   8  32 128]
#  [  4  32  64 256]]
# Failed to complete in trial number 708 in 500 steps
# [[  4   8  16  32]
#  [  2  16  32 128]
#  [  4  64 128   2]
#  [  2   8  32 256]]
# Failed to complete in trial number 709 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [ 16   2  64 128]
#  [  4   8 128   2]]
# Failed to complete in trial number 710 in 500 steps
# [[ 2  4  8 16]
#  [ 4  2 16 32]
#  [ 2  8 32 64]
#  [ 8 16 64  4]]
# Failed to complete in trial number 711 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [  8  16  64 128]
#  [  2   4   8  32]]
# Failed to complete in trial number 712 in 500 steps
# [[ 2  8  2 16]
#  [ 8  4  8 32]
#  [32 16  2 16]
#  [ 2  4 32 64]]
# Failed to complete in trial number 713 in 500 steps
# [[ 2  4  2  8]
#  [ 8  2  4 16]
#  [ 2 16 32  2]
#  [ 8 32  2 16]]
# Failed to complete in trial number 714 in 500 steps
# [[ 8  2  4  8]
#  [16  4  2 16]
#  [ 2  8 16 32]
#  [ 4 16 32 64]]
# Failed to complete in trial number 715 in 500 steps
# [[  2   4   8  16]
#  [  4   8  32  64]
#  [ 16  32 128   8]
#  [  2   4   8  64]]
# Failed to complete in trial number 716 in 500 steps
# [[  4   2   4   8]
#  [  2   8  32   2]
#  [ 16  32 128   8]
#  [  2   4  16  32]]
# Failed to complete in trial number 717 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   4]
#  [  8  16   2 128]
#  [  2  32 128   2]]
# Failed to complete in trial number 718 in 500 steps
# [[  4   2   4   8]
#  [  2   4  16  32]
#  [  8  16  64   2]
#  [  4  32   4 256]]
# Failed to complete in trial number 719 in 500 steps
# [[  2   4   2   8]
#  [  4  16   8  16]
#  [  8   2  32  64]
#  [ 16   4 128   2]]
# Failed to complete in trial number 720 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [ 16  32   2  64]
#  [  4   8  32 128]]
# Failed to complete in trial number 721 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16 32]
#  [ 8  2  4 64]
#  [32  8 64  2]]
# Failed to complete in trial number 722 in 500 steps
# [[  4   8   4  32]
#  [  2   4  32  64]
#  [  8  32  64   8]
#  [ 16   4   8 256]]
# Failed to complete in trial number 723 in 500 steps
# [[  2   4   2   8]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [ 16  64   2 256]]
# Failed to complete in trial number 724 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  16  32  64]
#  [ 16   4  64 128]]
# Failed to complete in trial number 725 in 500 steps
# [[  2   4   8  16]
#  [  4   2   4  64]
#  [  8  16  32 128]
#  [  2   8 128   2]]
# Failed to complete in trial number 726 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8  2 32]
#  [16  2 16 64]
#  [ 4 16 64  2]]
# Failed to complete in trial number 727 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32   4]
#  [  8  16 128   2]
#  [  2  64   4 128]]
# Failed to complete in trial number 728 in 500 steps
# [[  2   8   4   8]
#  [  4  16   8  32]
#  [  2   4  16 128]
#  [  4   2   4  16]]
# Failed to complete in trial number 729 in 500 steps
# [[  4   2   8  16]
#  [  2   8  32  64]
#  [  8  16  64 128]
#  [ 32  64 128 512]]
# Failed to complete in trial number 730 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  32]
#  [ 16  32  64 128]
#  [ 32  64 128 512]]
# Failed to complete in trial number 731 in 500 steps
# [[  4   2   4   2]
#  [  2   4   8  64]
#  [  4  16  64   2]
#  [ 16  32 128 256]]
# Failed to complete in trial number 732 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16   2]
#  [  8  16 128  64]
#  [ 16  32  64   8]]
# Failed to complete in trial number 733 in 500 steps
# [[  2   4   8   2]
#  [  4   8  32   4]
#  [  8  16  64  16]
#  [  2  64 128  64]]
# Failed to complete in trial number 734 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16  32]
#  [  8  16  32 128]
#  [ 16  32  64   4]]
# Failed to complete in trial number 735 in 500 steps
# [[  2   4   8   2]
#  [  4  16   2   4]
#  [  2   8  32   8]
#  [  4   2   8 256]]
# Failed to complete in trial number 736 in 500 steps
# [[  4   2  16   2]
#  [ 32  16  32   4]
#  [  4   8  64 128]
#  [ 32   2 128   8]]
# Failed to complete in trial number 737 in 500 steps
# [[  2   4   8   2]
#  [  4  16  32  16]
#  [  8  32  64 128]
#  [ 32  64   4 256]]
# Failed to complete in trial number 738 in 500 steps
# [[  2   4   8   2]
#  [  4   8  16   8]
#  [  8  16  32 128]
#  [ 16  64 128   4]]
# Failed to complete in trial number 739 in 500 steps
# [[  4   2   4   2]
#  [  2   4   8   4]
#  [  4  16  32  16]
#  [  2  32   8 128]]
# Failed to complete in trial number 740 in 500 steps
# [[  2   4   8  16]
#  [  4   8   2   8]
#  [  8  16  32   2]
#  [ 16  32  64 128]]
# Failed to complete in trial number 741 in 500 steps
# [[  2   4  16   4]
#  [  4  16  32  64]
#  [  8  32  64   2]
#  [ 16  64   2 128]]
# Failed to complete in trial number 742 in 500 steps
# [[  4   2   4   2]
#  [  2   4  16  64]
#  [  4   8  32 128]
#  [  8  16 128 256]]
# Failed to complete in trial number 743 in 500 steps
# [[  2   4   8  16]
#  [  4   8  16  32]
#  [  8  32   2 128]
#  [  2  16 128   2]]
# Failed to complete in trial number 744 in 500 steps
# [[ 2  4  8 16]
#  [ 4  8 16  4]
#  [ 8 16  2 32]
#  [ 4  2 32  4]]
# Failed to complete in trial number 745 in 500 steps
# [[  2   4   8  32]
#  [  4   8  16  64]
#  [  2  16  32   2]
#  [  8  32  64 128]]
# Failed to complete in trial number 746 in 500 steps
# [[  2   4   2   8]
#  [  8  16   4  16]
#  [ 16   2   8  32]
#  [  2   4  64 128]]
# Failed to complete in trial number 747 in 500 steps
# [[  2   4  16  32]
#  [  4  16  32  64]
#  [ 16  32  64 128]
#  [  2   8  16  64]]
# Failed to complete in trial number 748 in 500 steps
# [[  4   2   8  16]
#  [  8   4  16   2]
#  [  4  16  32 128]
#  [  2   4 128 256]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b4fa43599300> in <module>
#      61
#      62 if __name__ == "__main__":
# ---> 63     main()
#
# <ipython-input-9-b4fa43599300> in main()
#      21             stepno+=1
#      22
# ---> 23             action=dqn_agent.act(cur_state)
#      24
#      25             _,reward,done,_=env.step(action)
#
# <ipython-input-7-d843b40a9f21> in act(self, state)
#      44                     processed_state=process_log(allstates[i])
#      45                     #max from the 4 future Q_Values is appended in res
# ---> 46                     res.append(np.max(self.model.predict(processed_state)))
#      47
#      48             a=self.model.predict(process_log(state))
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1362
#    1363         # Case 1: generator-like. Input is Python generator, or Sequence object.
# -> 1364         if is_generator_or_sequence(x):
#    1365             return self.predict_generator(
#    1366                 x,
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/keras/engine/training_utils.py in is_generator_or_sequence(x)
#     638 def is_generator_or_sequence(x):
#     639     """Check if `x` is a Keras generator type."""
# --> 640     return inspect.isgenerator(x) or is_sequence(x)
#     641
#     642
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/keras/engine/training_utils.py in is_sequence(seq)
#     633     # TODO Dref360: Decide which pattern to follow. First needs a new TF Version.
#     634     return (getattr(seq, 'use_sequence_api', False)
# --> 635             or set(dir(Sequence())).issubset(set(dir(seq) + ['use_sequence_api'])))
#     636
#     637
#
# KeyboardInterrupt:
